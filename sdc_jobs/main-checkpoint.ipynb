# %%
#Attribution: https://github.com/indeedlabs/indeed-python
from indeed import IndeedClient
import re
client = IndeedClient(publisher ="9124561496937265")
import time
import sqlite3
import glob
from bs4 import BeautifulSoup # For HTML parsing
import urllib # Website connections
import re # Regular expressions
from time import sleep # To prevent overwhelming the server between connections
from collections import Counter # Keep track of our term counts
from nltk.corpus import stopwords # Filter out stopwords, such as 'the', 'or', 'and'
import pandas as pd # For converting results to a dataframe and bar chart plots
# %matplotlib inline

# %%
class Indeed_JobScrap():
    
    def __init__(self, db_fname, overwrite_db, job_requirements_ls):
        self.overwrite_db = overwrite_db
        self.db_fname = db_fname
        self.job_requirements_ls = job_requirements_ls
        self.job_items = ["jobtitle", "date", "company", "country", "state", 
                          "longitude", "latitude"]
        self.tracker = [] #tracker how many consecutives job_response ar null
        self.thres = 3 #if 3 consecutives job detail request empty, stop 
        self.listing = {}
        self.table_name = "jobs"
        self.dbname = "job_listings"
        self.url = 'https://www.indeed.com/viewjob?jk='
        self.other_tables = ['degrees', 'progskills', 'qualifications', 'expertise']
        self.sdc_expressions = ['autonomous vehicles', 'autonomous cars', 'self-driving cars', 
                                'self-driving car', 'self driving cars', 'self driving car',
                                'autonomous vehicles']
    
    def connect_db(self):
        sql_files = glob.glob('*.db')
        if (self.db_fname in sql_files) or (overwrite_db == False):
            self.conn = sqlite3.connect(self.db_fname)
            self.c = self.conn.cursor()
        else:
            #open connection to local file
            self.conn = sqlite3.connect(self.db_fname)
            self.c = self.conn.cursor()
            # Create table
            try:
                self.c.execute("CREATE TABLE {} (jobkey, jobtitle, employer, date, country, state, longitude, latitude)".format(self.table_name))
                print('Created Table: {} in database {}'.format(self.table_name, self.dbname) )
                self.conn.commit()
            except:
                print('Unable to create table {}'.format(self.table_name))
            for this_table in self.other_tables:
                try:
                    col_name = this_table + '_req'
                    self.c.execute("CREATE TABLE {} (jobkey, {})".format(this_table, col_name))
                    print('Created Table: {} in database {}'.format(this_table, self.dbname) )
                    # Save (commit) the changes
                    self.conn.commit()
                except:
                        print('Unable to create table {}'.format(this_table))
                
                
                
                
    def save2db(self, job_entry):
        '''
        Save job_entry data to database: 
        jobkey, jobtitle, employer, data, country, state, longitude, latitude,
        degrees, qualifications, expertise, progskills
        '''
        #check if job in db
        sql_select = "SELECT {}.jobkey FROM {} WHERE {}.jobkey = '{}';".format(self.table_name, self.table_name, self.table_name, job_entry['jobkey'])
        flag_jobindb = False
        flag_error = False
        try:
            self.c.execute(sql_select)
            result = self.c.fetchall()
            if len(result) != 0:
                flag_jobindb = True
        except:
            # Insert a row of data
            print('Unable to execute SQL query: SELECT')
            flag_error = True
        print('job entry already recorded: {}'.format(flag_jobindb))        
        if flag_jobindb == False:
            #add job entry to jobs table
            sql_insert = "INSERT INTO {} VALUES ('{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}');".format(self.table_name, 
            job_entry['jobkey'], job_entry['jobtitle'], job_entry['company'], job_entry['date'], 
            job_entry['country'], job_entry['state'], job_entry['longitude'], job_entry['latitude'])
            try:
                self.c.execute(sql_insert)
                self.conn.commit()
                print('Job entry saved in DB')
            except:
                print('Unable to save job entry in {}'.format(self.table_name))
            
            #add entry to other_tables
            for this_table in self.other_tables:
                if len(job_entry[this_table]) != 0:
                    for item in job_entry[this_table]:
                        sql_insert = "INSERT INTO {} VALUES ('{}','{}');".format(this_table, job_entry['jobkey'], item)
                        try:
                            self.c.execute(sql_insert)
                            self.conn.commit()
                        except:
                            print('Unable to save item {} in {}'.format(item, this_table))
        else:
            #update database
            sql_update = "UPDATE {} SET {}='{}', {}='{}', {}='{}', {}='{}', {}='{}', {}='{}', {}='{}' WHERE {}.jobkey={};".format(self.table_name, 
            'job_title', job_entry['jobtitle'], 'employer', job_entry['company'], 'date', job_entry['date'], 
            'country', job_entry['country'], 'state', job_entry['state'], 'longitude', 
            job_entry['longitude'], 'latitude', job_entry['latitude'], self.table_name, job_entry['jobkey'] )
            try:
                self.c.execute(sql_update)
                self.conn.commit()
                print('Job entry saved in DB')
            except:
                print('Unable to save job entry in {}'.format(self.table_name))
            
            #add/update entry to other_tables
                            

    def sanitize_text(self, text):
        try:
            text = text.decode('unicode_escape').encode('ascii', 'ignore') 
        except:
            pass

        #Remove special characters
        special_chars = "!@#$%^&*()[]{};:,./<>?\|`~=_"
        for special_char in special_chars:
            clean_text = text.replace(special_char, " ")
        #remove newline
        clean_text = " ".join(clean_text.split())
        clean_text = re.sub("[^a-zA-Z+2]"," ", clean_text)
        return clean_text
    
    
    
    def get_jobsListing(self, keywords, start, limit):
        query = ""
        if len(keywords) > 0:
            #build query
            for item in keywords:
                query = query +"+"+item
        
            params = {
                      'q' : query,
                      # 'l' : "austin",
                      'start': start,
                      'limit': limit, #maximum nbr of results returned
                      'userip' : "1.2.3.4",
                      'useragent' : "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_2)"
                     }

            return client.search(**params)
        else:
            return []                                                                                                            


                                                                                                      
                                                                                                                        
    def snif_jobDescription(self, jobkey):
        this_url = self.url+str(jobkey)
        flag_error = False
        try:
            site = urllib.request.urlopen(this_url).read() # Connect to the job posting
            soup_obj = BeautifulSoup(site, "lxml")
        except:
            print('page not found')
            flag_error = True
        
        if flag_error == False:
            # search for all <span tag
            spans = soup_obj.find_all('span', attrs={'id':"job_summary"})
            if len(spans) == 1:
                #convert soup object to text
                text = spans[0].get_text()
                #Cleaning text
                clean_text = self.sanitize_text(text)
                if ( any(x in clean_text for x in self.sdc_expressions)): #if text contains any of the sdc_expressions        
                    text_split = clean_text.split()
                    return text_split
                else:
                    return []
            else:
                return []


    def extract_jobRequirements(self, jobkey):
        #get text job description
        job_description_txt = self.snif_jobDescription(jobkey)
        #save job requirements in job_req
        job_req = {}
        #Initialize
        for i in self.job_requirements_ls:
            job_req[i] = []

        #better to scroll thru text once
        for idx, word in enumerate(job_description_txt):
            w_lower = word.lower()
            
            for key in self.job_requirements_ls:
                if key == 'expertise' or key == 'qualifications':
                    if w_lower in self.job_requirements_ls[key]:
                        if len(self.job_requirements_ls[key][w_lower])==0:
                            #the word has no child in list of job req  (like 'cs':[]) 
                            if len(job_req[key])==0:
                                job_req[key] = [w_lower]
                            elif w_lower not in job_req[key]:
                                job_req[key].append(w_lower)
                        else:
                            #check the word is not the last of the job_description (otherwise next_word does not exist)
                            if idx < len(job_description_txt)-1:
                                next_word = job_description_txt[idx+1].lower()
                                #check if expression=word+next_word is in our list of job_requirements of that key
                                if next_word in self.job_requirements_ls[key][w_lower]:
                                    expression = w_lower+" "+next_word
                                    if len(job_req[key])==0:
                                        job_req[key] = [expression]
                                    elif expression not in job_req[key]:
                                        job_req[key].append(expression)
                                
                else:
                    if w_lower in self.job_requirements_ls[key]:
                        if len(job_req[key])==0:
                            job_req[key] = [w_lower]
                        elif w_lower not in job_req[key]:
                            job_req[key].append(w_lower)
        
        return job_req

                            
    def record(self, keywords, start, limit):
        while len(self.tracker) < self.thres:
            #get more responses (pagination)
            query_response = self.get_jobsListing(keywords, start, limit)
            n_entry = 0
            print(start)
            for job_entry in query_response['results']:
                job_details = {}
                n_entry += 1
                print('********* Entry # {}'.format(n_entry))
                jobkey = job_entry['jobkey']
                job_details['jobkey'] = jobkey
                #Make a query on this jobkey
                job_entry_response = client.jobs(jobkeys = (jobkey, ))
                if len(job_entry_response['results']) > 0:
                    #reset tracker
                    self.tracker = []
                    job_entry_response = job_entry_response['results'][0]
                    ##save job specs (employer, title etc...)  ########
                    for job_item in self.job_items:
                        if job_item in job_entry_response:
                            job_details[job_item] = job_entry_response[job_item]
                        else:
                            job_details[job_item] = ""
                    
                    #extract job requirements from job description
                    job_req = self.extract_jobRequirements(jobkey)
                    job_specs = {**job_details, **job_req}
                    print(job_specs)
                    self.save2db(job_specs)       
                    time.sleep(1)
                    print('Jobkey {}'.format(jobkey))
                    print()

                else:
                    self.tracker.append(1)
            
            #check consistency n_entry and limit
            start = start + limit

# %%
degrees_ls = ['phd', 'ms', 'bsc', 'mba', 'master', 'masters', 'bachelors', 'bachelor', 'ba', 'bs']
qualifications_ls = {'cs':[], 'ce':[], 'ee':[], 'physics':[], 'electrical': ['engineering'], 'computer': ['science'],
                     'mechanical': ['engineering'], 'industrial': ['engineering']}
expertise_ls = {'machine': ['learning'], 'Deep': ['Learning'], 'computer': ['architecture'], 'Algorithms':[], 
                'GPU': ['computing'], 'parallel': ['programming'], 'Computer': ['Vision'], 
               'predictive': ['analytics'], 'vehicle':['design', 'development', 'regulations'],
               'autonomous':['vehicles'], 'robotics':[], 'radar':[], 'kinematics':[]}
progskills_ls = ['c++', 'c', 'c#', 'python', 'opencv', 'matlab', 'php', 'java', 'ruby', 'ros', 'tensorflow', 'keras']

job_requirements_ls = {'degrees': degrees_ls, 'qualifications': qualifications_ls, 'expertise': expertise_ls, 'progskills': progskills_ls}

#keywords = ['self-driving car']
#keywords = ['self-driving', 'car']
#keywords = ['autonomous', 'cars']
#keywords = ['autonomous vehicles']
#keywords = ['autonomous cars']
#keywords = ['autonomous-cars']
start = 0
limit = 25
db_fname = 'indeed.db'
overwrite_db = True

jobsScrap = Indeed_JobScrap(db_fname, overwrite_db, job_requirements_ls)
#connect to database
jobsScrap.connect_db()

#
jobsScrap.record(keywords, start, limit)
# Out:
# 0
# ********* Entry # 1
# {'company': 'NVIDIA', 'state': 'CA', 'jobtitle': 'Sr Autonomous Vehicle Control Engineer', 'progskills': ['matlab', 'c', 'c++'], 'country': 'US', 'qualifications': ['mechanical engineering', 'electrical engineering', 'computer science'], 'longitude': -121.95055, 'expertise': ['autonomous vehicles'], 'jobkey': 'd285a86c2007a2ca', 'date': 'Fri, 12 May 2017 22:40:13 GMT', 'degrees': ['phd', 'ms'], 'latitude': 37.35165}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey d285a86c2007a2ca
#
# ********* Entry # 2
# {'company': 'NVIDIA', 'state': 'OR', 'jobtitle': 'Deep Learning Performance Architect', 'progskills': ['python', 'c', 'c++'], 'country': 'US', 'qualifications': ['cs', 'ee', 'ce'], 'longitude': -122.8022, 'expertise': ['machine learning', 'computer architecture', 'parallel programming'], 'jobkey': '8d8fd08059b8c494', 'date': 'Wed, 26 Apr 2017 00:07:31 GMT', 'degrees': ['ms', 'phd'], 'latitude': 45.486263}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 8d8fd08059b8c494
#
# ********* Entry # 3
# {'company': 'Google', 'state': 'CA', 'jobtitle': 'Vehicle Test Engineer, Reliability, Waymo', 'progskills': ['matlab'], 'country': 'US', 'qualifications': ['mechanical engineering'], 'longitude': -120.47802, 'expertise': [], 'jobkey': '7c21c58d2fe15e2b', 'date': 'Sat, 08 Apr 2017 11:55:38 GMT', 'degrees': ['bs', 'master'], 'latitude': 37.29945}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 7c21c58d2fe15e2b
#
# ********* Entry # 4
# {'company': 'Google', 'state': 'MI', 'jobtitle': 'Vehicle Test Engineer, Waymo', 'progskills': ['python', 'c', 'c++'], 'country': 'US', 'qualifications': ['electrical engineering', 'computer science'], 'longitude': -83.47253, 'expertise': [], 'jobkey': '06b2eec28681fb7c', 'date': 'Thu, 06 Apr 2017 23:51:07 GMT', 'degrees': ['ba', 'bs'], 'latitude': 42.478024}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 06b2eec28681fb7c
#
# ********* Entry # 5
# {'company': 'Google', 'state': 'CA', 'jobtitle': 'Hardware Engineer, Manufacturing Test, Waymo', 'progskills': ['python'], 'country': 'US', 'qualifications': ['computer science', 'electrical engineering'], 'longitude': -122.08242, 'expertise': [], 'jobkey': 'f52c3e07088d359d', 'date': 'Thu, 06 Apr 2017 11:47:37 GMT', 'degrees': ['bachelor'], 'latitude': 37.384617}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey f52c3e07088d359d
#
# ********* Entry # 6
# {'company': 'Watson University', 'state': 'CO', 'jobtitle': 'VP of Programs - Watson U Boulder', 'progskills': ['c'], 'country': 'US', 'qualifications': [], 'longitude': -105.26923, 'expertise': [], 'jobkey': '206962c96e02c5c1', 'date': 'Tue, 25 Apr 2017 17:16:57 GMT', 'degrees': ['bachelor', 'bachelors', 'master'], 'latitude': 40.013737}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 206962c96e02c5c1
#
# ********* Entry # 7
# {'company': 'Watson University', 'state': 'FL', 'jobtitle': 'VP of Programs - Watson Institute at Lynn University', 'progskills': ['c'], 'country': 'US', 'qualifications': [], 'longitude': -80.08242, 'expertise': [], 'jobkey': '2925af331146a975', 'date': 'Tue, 25 Apr 2017 11:08:50 GMT', 'degrees': ['bachelors', 'master'], 'latitude': 26.357143}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 2925af331146a975
#
# ********* Entry # 8
# {'company': 'Google', 'state': 'CA', 'jobtitle': 'Product Manager, Waymo', 'progskills': [], 'country': 'US', 'qualifications': ['computer science', 'mechanical engineering'], 'longitude': -122.08242, 'expertise': ['autonomous vehicles', 'robotics', 'machine learning'], 'jobkey': '477920bea36b9157', 'date': 'Wed, 12 Apr 2017 12:11:27 GMT', 'degrees': ['ba', 'bs', 'master', 'mba'], 'latitude': 37.384617}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 477920bea36b9157
#
# ********* Entry # 9
# {'company': 'WonderHowTo', 'state': 'NY', 'jobtitle': 'Business Reporter Obsessed With Self-Driving Car Industry', 'progskills': [], 'country': 'US', 'qualifications': [], 'longitude': -74.00549, 'expertise': ['autonomous vehicles'], 'jobkey': '7242d2755bfc7e1f', 'date': 'Mon, 17 Apr 2017 21:24:23 GMT', 'degrees': [], 'latitude': 40.71154}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 7242d2755bfc7e1f
#
# ********* Entry # 10
# ********* Entry # 11
# {'company': 'NVIDIA', 'state': 'CA', 'jobtitle': 'Research Scientist (Deep Learning)', 'progskills': ['matlab', 'python', 'c++'], 'country': 'US', 'qualifications': ['electrical engineering', 'computer science'], 'longitude': -121.95055, 'expertise': ['machine learning', 'parallel programming'], 'jobkey': '11e03a3967ada562', 'date': 'Wed, 03 May 2017 22:18:37 GMT', 'degrees': ['phd'], 'latitude': 37.35165}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 11e03a3967ada562
#
# ********* Entry # 12
# {'company': 'Drive.ai', 'state': 'CA', 'jobtitle': 'Electrical Engineer', 'progskills': ['python', 'c++'], 'country': 'US', 'qualifications': ['ee', 'ce'], 'longitude': -122.08242, 'expertise': ['autonomous vehicles', 'robotics'], 'jobkey': 'dc55729e7e5d44c9', 'date': 'Thu, 27 Apr 2017 23:56:07 GMT', 'degrees': ['bs'], 'latitude': 37.384617}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey dc55729e7e5d44c9
#
# ********* Entry # 13
# {'company': 'Google', 'state': 'CA', 'jobtitle': 'Product Manager, Vehicle, Waymo', 'progskills': [], 'country': 'US', 'qualifications': ['mechanical engineering', 'electrical engineering', 'industrial engineering'], 'longitude': -122.08242, 'expertise': ['vehicle design', 'vehicle development', 'vehicle regulations', 'autonomous vehicles'], 'jobkey': 'fa7bb652d18fce60', 'date': 'Fri, 05 May 2017 10:02:18 GMT', 'degrees': ['bachelor', 'mba', 'masters'], 'latitude': 37.384617}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey fa7bb652d18fce60
#
# ********* Entry # 14
# {'company': 'Drive.ai', 'state': 'CA', 'jobtitle': 'Motion Planning Software Engineer', 'progskills': [], 'country': 'US', 'qualifications': ['cs', 'ee'], 'longitude': -122.08242, 'expertise': ['autonomous vehicles', 'radar'], 'jobkey': '84b10211ff5c5f49', 'date': 'Wed, 10 May 2017 16:56:10 GMT', 'degrees': ['ms', 'phd'], 'latitude': 37.384617}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 84b10211ff5c5f49
#
# ********* Entry # 15
# {'company': 'Drive.ai', 'state': 'CA', 'jobtitle': 'Simulation Engineer', 'progskills': ['c++', 'python'], 'country': 'US', 'qualifications': ['physics', 'computer science'], 'longitude': -122.08242, 'expertise': ['autonomous vehicles', 'robotics'], 'jobkey': '8ffdbe0434829389', 'date': 'Mon, 08 May 2017 05:55:41 GMT', 'degrees': ['ms', 'phd'], 'latitude': 37.384617}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 8ffdbe0434829389
#
# ********* Entry # 16
# {'company': 'Google', 'state': 'CA', 'jobtitle': 'Manufacturing Operations Manager, Waymo', 'progskills': [], 'country': 'US', 'qualifications': ['mechanical engineering', 'electrical engineering', 'industrial engineering'], 'longitude': -122.08242, 'expertise': [], 'jobkey': '2afdde817310d128', 'date': 'Thu, 06 Apr 2017 11:47:18 GMT', 'degrees': ['master'], 'latitude': 37.384617}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 2afdde817310d128
#
# ********* Entry # 17
# {'company': 'Google', 'state': 'CA', 'jobtitle': 'Manufacturing Process Engineer, Waymo', 'progskills': [], 'country': 'US', 'qualifications': ['mechanical engineering', 'electrical engineering', 'industrial engineering'], 'longitude': -122.08242, 'expertise': [], 'jobkey': '6fee986bf0785201', 'date': 'Fri, 05 May 2017 10:02:10 GMT', 'degrees': ['bachelor'], 'latitude': 37.384617}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 6fee986bf0785201
#
# ********* Entry # 18
# {'company': 'Udacity, Inc.', 'state': 'CA', 'jobtitle': 'Content Developer - Self Driving Car', 'progskills': ['c++', 'python', 'matlab', 'ros', 'tensorflow', 'opencv'], 'country': 'US', 'qualifications': [], 'longitude': -122.41758, 'expertise': ['machine learning', 'autonomous vehicles', 'robotics'], 'jobkey': '350338ff5c3ae930', 'date': 'Wed, 08 Mar 2017 02:15:43 GMT', 'degrees': [], 'latitude': 37.774727}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 350338ff5c3ae930
#
# ********* Entry # 19
# {'company': 'Drive.ai', 'state': 'CA', 'jobtitle': 'Controls Engineer', 'progskills': ['c++'], 'country': 'US', 'qualifications': ['computer science', 'mechanical engineering'], 'longitude': -122.08242, 'expertise': ['autonomous vehicles', 'robotics'], 'jobkey': '0e628b36a90aebc9', 'date': 'Fri, 14 Apr 2017 05:54:42 GMT', 'degrees': ['phd'], 'latitude': 37.384617}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 0e628b36a90aebc9
#
# ********* Entry # 20
# {'company': 'Google', 'state': 'CA', 'jobtitle': 'Radar Software Engineer, Waymo', 'progskills': ['matlab', 'c++'], 'country': 'US', 'qualifications': ['electrical engineering', 'computer science'], 'longitude': -122.08242, 'expertise': ['radar', 'kinematics'], 'jobkey': '9a688bd4adc6c725', 'date': 'Sat, 13 May 2017 10:25:51 GMT', 'degrees': ['bachelor', 'ms'], 'latitude': 37.384617}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 9a688bd4adc6c725
#
# ********* Entry # 21
# {'company': 'Udacity, Inc.', 'state': 'CA', 'jobtitle': 'Nanodegree Services Lead, Self Driving Car', 'progskills': [], 'country': 'US', 'qualifications': [], 'longitude': -122.41758, 'expertise': [], 'jobkey': '3a89b746d62f78e5', 'date': 'Fri, 31 Mar 2017 20:08:55 GMT', 'degrees': [], 'latitude': 37.774727}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 3a89b746d62f78e5
#
# ********* Entry # 22
# {'company': 'Google', 'state': 'CA', 'jobtitle': 'Head of FP&A, Waymo', 'progskills': [], 'country': 'US', 'qualifications': [], 'longitude': -122.08242, 'expertise': [], 'jobkey': 'e2e267374660d646', 'date': 'Thu, 06 Apr 2017 11:45:55 GMT', 'degrees': [], 'latitude': 37.384617}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey e2e267374660d646
#
# ********* Entry # 23
# {'company': 'Google', 'state': 'CA', 'jobtitle': 'Remote Testing Facility Site Program Manager, Waymo', 'progskills': [], 'country': 'US', 'qualifications': [], 'longitude': -122.08242, 'expertise': [], 'jobkey': '8960370f01fdbf3f', 'date': 'Thu, 06 Apr 2017 11:52:14 GMT', 'degrees': [], 'latitude': 37.384617}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 8960370f01fdbf3f
#
# ********* Entry # 24
# {'company': 'NVIDIA', 'state': 'CA', 'jobtitle': 'Deep Learning Computer Architect', 'progskills': ['tensorflow', 'c++', 'python'], 'country': 'US', 'qualifications': ['computer science', 'electrical engineering'], 'longitude': -121.95055, 'expertise': ['computer architecture', 'machine learning'], 'jobkey': '5564820642c7dcf5', 'date': 'Tue, 14 Mar 2017 23:24:48 GMT', 'degrees': ['ms', 'phd'], 'latitude': 37.35165}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 5564820642c7dcf5
#
# ********* Entry # 25
# {'company': 'Google', 'state': 'CA', 'jobtitle': 'User Experience Research, Lead, Waymo', 'progskills': [], 'country': 'US', 'qualifications': [], 'longitude': -122.08242, 'expertise': [], 'jobkey': '6ae23717c4c474be', 'date': 'Wed, 01 Mar 2017 16:25:22 GMT', 'degrees': ['master'], 'latitude': 37.384617}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 6ae23717c4c474be
#
# 25
# ********* Entry # 1
# {'company': 'nuTonomy', 'state': 'MA', 'jobtitle': 'Software Test Engineer', 'progskills': ['c++', 'python'], 'country': 'US', 'qualifications': ['computer science', 'physics'], 'longitude': -71.10439, 'expertise': ['autonomous vehicles', 'robotics'], 'jobkey': '060978e2ad6b74cc', 'date': 'Sun, 02 Apr 2017 05:55:08 GMT', 'degrees': ['bs', 'ms'], 'latitude': 42.373627}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 060978e2ad6b74cc
#
# ********* Entry # 2
# {'company': 'Drive.ai', 'state': 'CA', 'jobtitle': 'Director of Robotics', 'progskills': [], 'country': 'US', 'qualifications': ['electrical engineering', 'mechanical engineering', 'computer science'], 'longitude': -122.08242, 'expertise': ['autonomous vehicles', 'robotics'], 'jobkey': '9fc48fe877608c7d', 'date': 'Mon, 10 Apr 2017 23:05:27 GMT', 'degrees': ['phd'], 'latitude': 37.384617}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 9fc48fe877608c7d
#
# ********* Entry # 3
# {'company': 'Drive.ai', 'state': 'CA', 'jobtitle': 'Data Annotator', 'progskills': [], 'country': 'US', 'qualifications': [], 'longitude': -122.08242, 'expertise': [], 'jobkey': 'a6389aa6dab35a6a', 'date': 'Tue, 07 Mar 2017 19:40:52 GMT', 'degrees': [], 'latitude': 37.384617}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey a6389aa6dab35a6a
#
# ********* Entry # 4
# {'company': 'Drive.ai', 'state': 'CA', 'jobtitle': 'Robotics Systems Engineer', 'progskills': ['c++', 'python'], 'country': 'US', 'qualifications': ['computer science'], 'longitude': -122.08242, 'expertise': ['autonomous vehicles', 'robotics'], 'jobkey': '04687ffc54291f58', 'date': 'Thu, 27 Apr 2017 23:55:50 GMT', 'degrees': ['ms', 'phd', 'bs'], 'latitude': 37.384617}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 04687ffc54291f58
#
# ********* Entry # 5
# {'company': 'Modis', 'state': 'CA', 'jobtitle': 'Entry Level Software Quality Operations (Physics, Math, Statisti', 'progskills': [], 'country': 'US', 'qualifications': ['physics'], 'longitude': -122.08242, 'expertise': [], 'jobkey': '398ed43726168777', 'date': 'Fri, 12 May 2017 22:55:26 GMT', 'degrees': ['bs', 'ba'], 'latitude': 37.384617}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 398ed43726168777
#
# ********* Entry # 6
# ********* Entry # 7
# {'company': 'Drive.ai', 'state': 'CA', 'jobtitle': 'Software Engineer - Mapping', 'progskills': ['c++', 'python'], 'country': 'US', 'qualifications': ['computer science'], 'longitude': -122.08242, 'expertise': ['autonomous vehicles', 'radar', 'robotics'], 'jobkey': 'db6fb0d70556ba93', 'date': 'Thu, 27 Apr 2017 23:58:59 GMT', 'degrees': ['phd'], 'latitude': 37.384617}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey db6fb0d70556ba93
#
# ********* Entry # 8
# {'company': '滴滴打车', 'state': '', 'jobtitle': 'Research Scientist-Autonomous Vehicle(J14137)', 'progskills': ['c++', 'python'], 'country': 'US', 'qualifications': [], 'longitude': '', 'expertise': ['machine learning'], 'jobkey': '68c5b19d7087066d', 'date': 'Mon, 20 Feb 2017 12:44:07 GMT', 'degrees': ['phd'], 'latitude': ''}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 68c5b19d7087066d
#
# ********* Entry # 9
# {'company': 'Google', 'state': 'CA', 'jobtitle': 'Software Test Engineer, Waymo', 'progskills': ['python'], 'country': 'US', 'qualifications': ['computer science', 'electrical engineering'], 'longitude': -122.08242, 'expertise': [], 'jobkey': 'b319bea074773942', 'date': 'Thu, 06 Apr 2017 11:50:42 GMT', 'degrees': ['bachelor'], 'latitude': 37.384617}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey b319bea074773942
#
# ********* Entry # 10
# {'company': 'Google', 'state': 'CA', 'jobtitle': 'Technical Program Manager, Waymo', 'progskills': [], 'country': 'US', 'qualifications': [], 'longitude': -122.08242, 'expertise': [], 'jobkey': 'fa4ae2696ba39faa', 'date': 'Thu, 16 Feb 2017 15:40:29 GMT', 'degrees': [], 'latitude': 37.384617}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey fa4ae2696ba39faa
#
# ********* Entry # 11
# {'company': 'Adecco', 'state': 'AZ', 'jobtitle': 'Fleet Systems Operator--020094', 'progskills': [], 'country': 'US', 'qualifications': ['ce'], 'longitude': -111.87363, 'expertise': [], 'jobkey': '285b0d294da8a5eb', 'date': 'Fri, 12 May 2017 20:30:44 GMT', 'degrees': ['bachelor'], 'latitude': 33.31868}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 285b0d294da8a5eb
#
# ********* Entry # 12
# ********* Entry # 13
# {'company': 'Jobspring Partners', 'state': 'IL', 'jobtitle': 'Open-source Guru', 'progskills': ['ruby', 'java', 'python', 'c', 'php'], 'country': 'US', 'qualifications': [], 'longitude': -87.64835, 'expertise': [], 'jobkey': 'd2d763b783db1815', 'date': 'Tue, 09 May 2017 23:29:37 GMT', 'degrees': [], 'latitude': 41.8489}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey d2d763b783db1815
#
# ********* Entry # 14
# {'company': 'Uber', 'state': 'CA', 'jobtitle': 'Software Engineer - Cloud', 'progskills': ['c++', 'python'], 'country': 'US', 'qualifications': [], 'longitude': -122.15385, 'expertise': [], 'jobkey': '46b3f65ed5db7494', 'date': 'Tue, 21 Mar 2017 02:06:51 GMT', 'degrees': [], 'latitude': 37.406593}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 46b3f65ed5db7494
#
# ********* Entry # 15
# {'company': 'Google', 'state': 'CA', 'jobtitle': 'Technical Program Manager, Systems Engineering, Waymo', 'progskills': ['python', 'java', 'c++'], 'country': 'US', 'qualifications': ['computer science'], 'longitude': -122.08242, 'expertise': [], 'jobkey': 'ed84ce5bb754f374', 'date': 'Thu, 06 Apr 2017 11:45:44 GMT', 'degrees': ['bs'], 'latitude': 37.384617}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey ed84ce5bb754f374
#
# ********* Entry # 16
# {'company': 'Google', 'state': 'CA', 'jobtitle': 'Reliability Engineering Lab Manager, Waymo', 'progskills': [], 'country': 'US', 'qualifications': [], 'longitude': -122.08242, 'expertise': [], 'jobkey': 'ac23a7dfebf38996', 'date': 'Thu, 06 Apr 2017 11:45:36 GMT', 'degrees': [], 'latitude': 37.384617}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey ac23a7dfebf38996
#
# ********* Entry # 17
# {'company': 'Drive.ai', 'state': 'CA', 'jobtitle': 'Senior Software Engineer', 'progskills': ['c', 'c++', 'python', 'ros', 'opencv'], 'country': 'US', 'qualifications': ['cs'], 'longitude': -122.08242, 'expertise': ['autonomous vehicles', 'robotics', 'radar'], 'jobkey': 'a2452a92e85854d4', 'date': 'Fri, 14 Apr 2017 05:54:09 GMT', 'degrees': ['bs', 'ms'], 'latitude': 37.384617}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey a2452a92e85854d4
#
# ********* Entry # 18
# ********* Entry # 19
# {'company': 'Drive.ai', 'state': 'CA', 'jobtitle': 'Mechanical Design Engineer', 'progskills': [], 'country': 'US', 'qualifications': ['mechanical engineering'], 'longitude': -122.08242, 'expertise': ['autonomous vehicles', 'robotics', 'radar'], 'jobkey': '87c1e26d27668e05', 'date': 'Fri, 03 Mar 2017 03:12:03 GMT', 'degrees': ['bs', 'ms', 'phd'], 'latitude': 37.384617}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 87c1e26d27668e05
#
# ********* Entry # 20
# {'company': 'Adecco: USA', 'state': 'AZ', 'jobtitle': 'Fleet Systems Operator', 'progskills': [], 'country': 'US', 'qualifications': ['ce'], 'longitude': -111.84066, 'expertise': [], 'jobkey': '043e5a5d74d5e430', 'date': 'Fri, 21 Apr 2017 11:58:19 GMT', 'degrees': ['bachelor'], 'latitude': 33.304947}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 043e5a5d74d5e430
#
# ********* Entry # 21
# {'company': 'Mobileye', 'state': 'WA', 'jobtitle': 'Sales Executive', 'progskills': [], 'country': 'US', 'qualifications': [], 'longitude': -122.32967, 'expertise': [], 'jobkey': 'efa9989fbf35e373', 'date': 'Tue, 16 May 2017 00:21:41 GMT', 'degrees': [], 'latitude': 47.604397}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey efa9989fbf35e373
#
# ********* Entry # 22
# {'company': '滴滴打车', 'state': '', 'jobtitle': 'Software Engineer-Autonomous Vehicle(J14131)', 'progskills': ['c++'], 'country': 'US', 'qualifications': ['computer science'], 'longitude': '', 'expertise': ['machine learning'], 'jobkey': 'fb741b222fe57792', 'date': 'Mon, 20 Feb 2017 12:44:11 GMT', 'degrees': ['bachelor', 'master'], 'latitude': ''}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey fb741b222fe57792
#
# ********* Entry # 23
# {'company': '滴滴打车', 'state': '', 'jobtitle': 'GPU Software Engineer-Autonomous Vehicle(J14138)', 'progskills': [], 'country': 'US', 'qualifications': [], 'longitude': '', 'expertise': [], 'jobkey': '414d156da88ad8dc', 'date': 'Mon, 20 Feb 2017 12:44:07 GMT', 'degrees': [], 'latitude': ''}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 414d156da88ad8dc
#
# ********* Entry # 24
# {'company': 'Continental', 'state': 'CA', 'jobtitle': 'Senior Software Engineer - Backend', 'progskills': [], 'country': 'US', 'qualifications': [], 'longitude': -121.89011, 'expertise': [], 'jobkey': 'eec26535d3ab0f0f', 'date': 'Wed, 26 Apr 2017 03:52:08 GMT', 'degrees': [], 'latitude': 37.337914}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey eec26535d3ab0f0f
#
# ********* Entry # 25
# {'company': 'Volkswagen Group of America, Inc.', 'state': 'CA', 'jobtitle': 'Sr. Technical Product Engineer - Autonomous Driving', 'progskills': [], 'country': 'US', 'qualifications': ['computer science'], 'longitude': -122.2762, 'expertise': ['robotics', 'machine learning'], 'jobkey': '100d524369c71fe2', 'date': 'Wed, 15 Feb 2017 04:59:22 GMT', 'degrees': ['bsc', 'phd'], 'latitude': 37.519276}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 100d524369c71fe2
#
# 50
# ********* Entry # 1
# {'company': 'Audi Canada', 'state': 'CA', 'jobtitle': 'Sr. Technical Product Engineer - Autonomous Driving', 'progskills': [], 'country': 'US', 'qualifications': ['computer science'], 'longitude': -122.27473, 'expertise': ['robotics', 'machine learning'], 'jobkey': '82a9e0df6b10800c', 'date': 'Wed, 15 Feb 2017 02:19:03 GMT', 'degrees': ['bsc', 'phd'], 'latitude': 37.51923}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 82a9e0df6b10800c
#
# ********* Entry # 2
# {'company': 'Mobileye', 'state': 'OH', 'jobtitle': 'Sales Executive', 'progskills': [], 'country': 'US', 'qualifications': [], 'longitude': -82.99451, 'expertise': [], 'jobkey': '05177a5668ea227f', 'date': 'Tue, 16 May 2017 02:14:41 GMT', 'degrees': [], 'latitude': 39.95879}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 05177a5668ea227f
#
# ********* Entry # 3
# {'company': 'Mobileye', 'state': 'CA', 'jobtitle': 'Sales Executive', 'progskills': [], 'country': 'US', 'qualifications': [], 'longitude': -121.48901, 'expertise': [], 'jobkey': '007d5ca4c4bdc749', 'date': 'Tue, 16 May 2017 00:23:51 GMT', 'degrees': [], 'latitude': 38.57967}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 007d5ca4c4bdc749
#
# ********* Entry # 4
# {'company': 'Mobileye', 'state': 'OR', 'jobtitle': 'Sales Executive', 'progskills': [], 'country': 'US', 'qualifications': [], 'longitude': -122.67583, 'expertise': [], 'jobkey': '16ca9cf3203b02fb', 'date': 'Tue, 16 May 2017 00:18:10 GMT', 'degrees': [], 'latitude': 45.521976}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 16ca9cf3203b02fb
#
# ********* Entry # 5
# {'company': 'Drive.ai', 'state': 'CA', 'jobtitle': 'Senior Software Engineer-Tools and Infrastructure', 'progskills': ['tensorflow', 'python', 'ruby', 'java', 'c++'], 'country': 'US', 'qualifications': [], 'longitude': -122.08242, 'expertise': ['autonomous vehicles'], 'jobkey': 'dce8abc4fcc8920a', 'date': 'Fri, 28 Apr 2017 20:03:11 GMT', 'degrees': [], 'latitude': 37.384617}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey dce8abc4fcc8920a
#
# ********* Entry # 6
# {'company': 'NVIDIA', 'state': 'CA', 'jobtitle': 'Deep Learning Software Engineering Manager', 'progskills': ['python', 'c++', 'tensorflow'], 'country': 'US', 'qualifications': ['computer science'], 'longitude': -121.95055, 'expertise': ['autonomous vehicles', 'radar', 'machine learning'], 'jobkey': '32e29fd95f9cfd42', 'date': 'Wed, 22 Mar 2017 04:33:15 GMT', 'degrees': ['masters', 'phd'], 'latitude': 37.35165}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 32e29fd95f9cfd42
#
# ********* Entry # 7
# {'company': 'Jobspring Partners', 'state': 'IL', 'jobtitle': 'OOP Expert', 'progskills': ['ruby', 'java', 'python', 'c', 'php'], 'country': 'US', 'qualifications': [], 'longitude': -87.62637, 'expertise': [], 'jobkey': '06ac8eb70143ad62', 'date': 'Wed, 08 Mar 2017 21:17:45 GMT', 'degrees': [], 'latitude': 41.87912}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 06ac8eb70143ad62
#
# ********* Entry # 8
# {'company': 'TEKSystems', 'state': 'CA', 'jobtitle': 'Front End Developer', 'progskills': [], 'country': 'US', 'qualifications': [], 'longitude': -122.39982, 'expertise': [], 'jobkey': '15e5790def47ea12', 'date': 'Tue, 09 May 2017 23:05:54 GMT', 'degrees': [], 'latitude': 37.78505}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 15e5790def47ea12
#
# ********* Entry # 9
# {'company': 'Workbridge Associates', 'state': 'CA', 'jobtitle': 'Principal Data Scientist', 'progskills': ['python', 'java'], 'country': 'US', 'qualifications': ['computer science'], 'longitude': -121.89224, 'expertise': ['machine learning', 'robotics'], 'jobkey': 'f0735102e24122d7', 'date': 'Fri, 21 Apr 2017 03:16:16 GMT', 'degrees': ['ms'], 'latitude': 37.33181}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey f0735102e24122d7
#
# ********* Entry # 10
# {'company': 'Stride Search', 'state': 'CA', 'jobtitle': 'Perception Engineer', 'progskills': ['c++', 'ros', 'opencv'], 'country': 'US', 'qualifications': ['computer science'], 'longitude': -122.41758, 'expertise': ['robotics', 'machine learning'], 'jobkey': '3fecae81fbed7c32', 'date': 'Tue, 04 Apr 2017 06:25:44 GMT', 'degrees': ['bs', 'ms', 'phd'], 'latitude': 37.774727}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 3fecae81fbed7c32
#
# ********* Entry # 11
# {'company': 'Modis', 'state': 'CA', 'jobtitle': 'Software Release Coordinator', 'progskills': [], 'country': 'US', 'qualifications': ['physics'], 'longitude': -122.08242, 'expertise': [], 'jobkey': '715af6682190fb6b', 'date': 'Tue, 28 Feb 2017 19:30:26 GMT', 'degrees': ['bs', 'ba'], 'latitude': 37.384617}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 715af6682190fb6b
#
# 75
# ********* Entry # 1
# {'company': 'Audi Canada', 'state': 'CA', 'jobtitle': 'Sr. Technical Product Engineer - Autonomous Driving', 'progskills': [], 'country': 'US', 'qualifications': ['computer science'], 'longitude': -122.27473, 'expertise': ['robotics', 'machine learning'], 'jobkey': '82a9e0df6b10800c', 'date': 'Wed, 15 Feb 2017 02:19:03 GMT', 'degrees': ['bsc', 'phd'], 'latitude': 37.51923}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 82a9e0df6b10800c
#
# ********* Entry # 2
# {'company': 'Mobileye', 'state': 'OH', 'jobtitle': 'Sales Executive', 'progskills': [], 'country': 'US', 'qualifications': [], 'longitude': -82.99451, 'expertise': [], 'jobkey': '05177a5668ea227f', 'date': 'Tue, 16 May 2017 02:14:41 GMT', 'degrees': [], 'latitude': 39.95879}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 05177a5668ea227f
#
# ********* Entry # 3
# {'company': 'Mobileye', 'state': 'CA', 'jobtitle': 'Sales Executive', 'progskills': [], 'country': 'US', 'qualifications': [], 'longitude': -121.48901, 'expertise': [], 'jobkey': '007d5ca4c4bdc749', 'date': 'Tue, 16 May 2017 00:23:51 GMT', 'degrees': [], 'latitude': 38.57967}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 007d5ca4c4bdc749
#
# ********* Entry # 4
# {'company': 'Mobileye', 'state': 'OR', 'jobtitle': 'Sales Executive', 'progskills': [], 'country': 'US', 'qualifications': [], 'longitude': -122.67583, 'expertise': [], 'jobkey': '16ca9cf3203b02fb', 'date': 'Tue, 16 May 2017 00:18:10 GMT', 'degrees': [], 'latitude': 45.521976}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 16ca9cf3203b02fb
#
# ********* Entry # 5
# {'company': 'Drive.ai', 'state': 'CA', 'jobtitle': 'Senior Software Engineer-Tools and Infrastructure', 'progskills': ['tensorflow', 'python', 'ruby', 'java', 'c++'], 'country': 'US', 'qualifications': [], 'longitude': -122.08242, 'expertise': ['autonomous vehicles'], 'jobkey': 'dce8abc4fcc8920a', 'date': 'Fri, 28 Apr 2017 20:03:11 GMT', 'degrees': [], 'latitude': 37.384617}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey dce8abc4fcc8920a
#
# ********* Entry # 6
# {'company': 'NVIDIA', 'state': 'CA', 'jobtitle': 'Deep Learning Software Engineering Manager', 'progskills': ['python', 'c++', 'tensorflow'], 'country': 'US', 'qualifications': ['computer science'], 'longitude': -121.95055, 'expertise': ['autonomous vehicles', 'radar', 'machine learning'], 'jobkey': '32e29fd95f9cfd42', 'date': 'Wed, 22 Mar 2017 04:33:15 GMT', 'degrees': ['masters', 'phd'], 'latitude': 37.35165}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 32e29fd95f9cfd42
#
# ********* Entry # 7
# {'company': 'Jobspring Partners', 'state': 'IL', 'jobtitle': 'OOP Expert', 'progskills': ['ruby', 'java', 'python', 'c', 'php'], 'country': 'US', 'qualifications': [], 'longitude': -87.62637, 'expertise': [], 'jobkey': '06ac8eb70143ad62', 'date': 'Wed, 08 Mar 2017 21:17:45 GMT', 'degrees': [], 'latitude': 41.87912}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 06ac8eb70143ad62
#
# ********* Entry # 8
# {'company': 'TEKSystems', 'state': 'CA', 'jobtitle': 'Front End Developer', 'progskills': [], 'country': 'US', 'qualifications': [], 'longitude': -122.39982, 'expertise': [], 'jobkey': '15e5790def47ea12', 'date': 'Tue, 09 May 2017 23:05:54 GMT', 'degrees': [], 'latitude': 37.78505}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 15e5790def47ea12
#
# ********* Entry # 9
# {'company': 'Workbridge Associates', 'state': 'CA', 'jobtitle': 'Principal Data Scientist', 'progskills': ['python', 'java'], 'country': 'US', 'qualifications': ['computer science'], 'longitude': -121.89224, 'expertise': ['machine learning', 'robotics'], 'jobkey': 'f0735102e24122d7', 'date': 'Fri, 21 Apr 2017 03:16:16 GMT', 'degrees': ['ms'], 'latitude': 37.33181}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey f0735102e24122d7
#
# ********* Entry # 10
# {'company': 'Stride Search', 'state': 'CA', 'jobtitle': 'Perception Engineer', 'progskills': ['c++', 'ros', 'opencv'], 'country': 'US', 'qualifications': ['computer science'], 'longitude': -122.41758, 'expertise': ['robotics', 'machine learning'], 'jobkey': '3fecae81fbed7c32', 'date': 'Tue, 04 Apr 2017 06:25:44 GMT', 'degrees': ['bs', 'ms', 'phd'], 'latitude': 37.774727}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 3fecae81fbed7c32
#
# ********* Entry # 11
# {'company': 'Modis', 'state': 'CA', 'jobtitle': 'Software Release Coordinator', 'progskills': [], 'country': 'US', 'qualifications': ['physics'], 'longitude': -122.08242, 'expertise': [], 'jobkey': '715af6682190fb6b', 'date': 'Tue, 28 Feb 2017 19:30:26 GMT', 'degrees': ['bs', 'ba'], 'latitude': 37.384617}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 715af6682190fb6b
#
# 100
# ********* Entry # 1
# {'company': 'Audi Canada', 'state': 'CA', 'jobtitle': 'Sr. Technical Product Engineer - Autonomous Driving', 'progskills': [], 'country': 'US', 'qualifications': ['computer science'], 'longitude': -122.27473, 'expertise': ['robotics', 'machine learning'], 'jobkey': '82a9e0df6b10800c', 'date': 'Wed, 15 Feb 2017 02:19:03 GMT', 'degrees': ['bsc', 'phd'], 'latitude': 37.51923}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 82a9e0df6b10800c
#
# ********* Entry # 2
# {'company': 'Mobileye', 'state': 'OH', 'jobtitle': 'Sales Executive', 'progskills': [], 'country': 'US', 'qualifications': [], 'longitude': -82.99451, 'expertise': [], 'jobkey': '05177a5668ea227f', 'date': 'Tue, 16 May 2017 02:14:41 GMT', 'degrees': [], 'latitude': 39.95879}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 05177a5668ea227f
#
# ********* Entry # 3
# {'company': 'Mobileye', 'state': 'CA', 'jobtitle': 'Sales Executive', 'progskills': [], 'country': 'US', 'qualifications': [], 'longitude': -121.48901, 'expertise': [], 'jobkey': '007d5ca4c4bdc749', 'date': 'Tue, 16 May 2017 00:23:51 GMT', 'degrees': [], 'latitude': 38.57967}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 007d5ca4c4bdc749
#
# ********* Entry # 4
# {'company': 'Mobileye', 'state': 'OR', 'jobtitle': 'Sales Executive', 'progskills': [], 'country': 'US', 'qualifications': [], 'longitude': -122.67583, 'expertise': [], 'jobkey': '16ca9cf3203b02fb', 'date': 'Tue, 16 May 2017 00:18:10 GMT', 'degrees': [], 'latitude': 45.521976}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 16ca9cf3203b02fb
#
# ********* Entry # 5
# {'company': 'Drive.ai', 'state': 'CA', 'jobtitle': 'Senior Software Engineer-Tools and Infrastructure', 'progskills': ['tensorflow', 'python', 'ruby', 'java', 'c++'], 'country': 'US', 'qualifications': [], 'longitude': -122.08242, 'expertise': ['autonomous vehicles'], 'jobkey': 'dce8abc4fcc8920a', 'date': 'Fri, 28 Apr 2017 20:03:11 GMT', 'degrees': [], 'latitude': 37.384617}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey dce8abc4fcc8920a
#
# ********* Entry # 6
# {'company': 'NVIDIA', 'state': 'CA', 'jobtitle': 'Deep Learning Software Engineering Manager', 'progskills': ['python', 'c++', 'tensorflow'], 'country': 'US', 'qualifications': ['computer science'], 'longitude': -121.95055, 'expertise': ['autonomous vehicles', 'radar', 'machine learning'], 'jobkey': '32e29fd95f9cfd42', 'date': 'Wed, 22 Mar 2017 04:33:15 GMT', 'degrees': ['masters', 'phd'], 'latitude': 37.35165}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 32e29fd95f9cfd42
#
# ********* Entry # 7
# {'company': 'Jobspring Partners', 'state': 'IL', 'jobtitle': 'OOP Expert', 'progskills': ['ruby', 'java', 'python', 'c', 'php'], 'country': 'US', 'qualifications': [], 'longitude': -87.62637, 'expertise': [], 'jobkey': '06ac8eb70143ad62', 'date': 'Wed, 08 Mar 2017 21:17:45 GMT', 'degrees': [], 'latitude': 41.87912}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 06ac8eb70143ad62
#
# ********* Entry # 8
# {'company': 'TEKSystems', 'state': 'CA', 'jobtitle': 'Front End Developer', 'progskills': [], 'country': 'US', 'qualifications': [], 'longitude': -122.39982, 'expertise': [], 'jobkey': '15e5790def47ea12', 'date': 'Tue, 09 May 2017 23:05:54 GMT', 'degrees': [], 'latitude': 37.78505}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 15e5790def47ea12
#
# ********* Entry # 9
# {'company': 'Workbridge Associates', 'state': 'CA', 'jobtitle': 'Principal Data Scientist', 'progskills': ['python', 'java'], 'country': 'US', 'qualifications': ['computer science'], 'longitude': -121.89224, 'expertise': ['machine learning', 'robotics'], 'jobkey': 'f0735102e24122d7', 'date': 'Fri, 21 Apr 2017 03:16:16 GMT', 'degrees': ['ms'], 'latitude': 37.33181}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey f0735102e24122d7
#
# ********* Entry # 10
# {'company': 'Stride Search', 'state': 'CA', 'jobtitle': 'Perception Engineer', 'progskills': ['c++', 'ros', 'opencv'], 'country': 'US', 'qualifications': ['computer science'], 'longitude': -122.41758, 'expertise': ['robotics', 'machine learning'], 'jobkey': '3fecae81fbed7c32', 'date': 'Tue, 04 Apr 2017 06:25:44 GMT', 'degrees': ['bs', 'ms', 'phd'], 'latitude': 37.774727}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 3fecae81fbed7c32
#
# ********* Entry # 11
# {'company': 'Modis', 'state': 'CA', 'jobtitle': 'Software Release Coordinator', 'progskills': [], 'country': 'US', 'qualifications': ['physics'], 'longitude': -122.08242, 'expertise': [], 'jobkey': '715af6682190fb6b', 'date': 'Tue, 28 Feb 2017 19:30:26 GMT', 'degrees': ['bs', 'ba'], 'latitude': 37.384617}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 715af6682190fb6b
#
# 125
# ********* Entry # 1
# {'company': 'Audi Canada', 'state': 'CA', 'jobtitle': 'Sr. Technical Product Engineer - Autonomous Driving', 'progskills': [], 'country': 'US', 'qualifications': ['computer science'], 'longitude': -122.27473, 'expertise': ['robotics', 'machine learning'], 'jobkey': '82a9e0df6b10800c', 'date': 'Wed, 15 Feb 2017 02:19:03 GMT', 'degrees': ['bsc', 'phd'], 'latitude': 37.51923}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 82a9e0df6b10800c
#
# ********* Entry # 2
# {'company': 'Mobileye', 'state': 'OH', 'jobtitle': 'Sales Executive', 'progskills': [], 'country': 'US', 'qualifications': [], 'longitude': -82.99451, 'expertise': [], 'jobkey': '05177a5668ea227f', 'date': 'Tue, 16 May 2017 02:14:41 GMT', 'degrees': [], 'latitude': 39.95879}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 05177a5668ea227f
#
# ********* Entry # 3
# {'company': 'Mobileye', 'state': 'CA', 'jobtitle': 'Sales Executive', 'progskills': [], 'country': 'US', 'qualifications': [], 'longitude': -121.48901, 'expertise': [], 'jobkey': '007d5ca4c4bdc749', 'date': 'Tue, 16 May 2017 00:23:51 GMT', 'degrees': [], 'latitude': 38.57967}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 007d5ca4c4bdc749
#
# ********* Entry # 4
# {'company': 'Mobileye', 'state': 'OR', 'jobtitle': 'Sales Executive', 'progskills': [], 'country': 'US', 'qualifications': [], 'longitude': -122.67583, 'expertise': [], 'jobkey': '16ca9cf3203b02fb', 'date': 'Tue, 16 May 2017 00:18:10 GMT', 'degrees': [], 'latitude': 45.521976}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 16ca9cf3203b02fb
#
# ********* Entry # 5
# {'company': 'Drive.ai', 'state': 'CA', 'jobtitle': 'Senior Software Engineer-Tools and Infrastructure', 'progskills': ['tensorflow', 'python', 'ruby', 'java', 'c++'], 'country': 'US', 'qualifications': [], 'longitude': -122.08242, 'expertise': ['autonomous vehicles'], 'jobkey': 'dce8abc4fcc8920a', 'date': 'Fri, 28 Apr 2017 20:03:11 GMT', 'degrees': [], 'latitude': 37.384617}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey dce8abc4fcc8920a
#
# ********* Entry # 6
# {'company': 'NVIDIA', 'state': 'CA', 'jobtitle': 'Deep Learning Software Engineering Manager', 'progskills': ['python', 'c++', 'tensorflow'], 'country': 'US', 'qualifications': ['computer science'], 'longitude': -121.95055, 'expertise': ['autonomous vehicles', 'radar', 'machine learning'], 'jobkey': '32e29fd95f9cfd42', 'date': 'Wed, 22 Mar 2017 04:33:15 GMT', 'degrees': ['masters', 'phd'], 'latitude': 37.35165}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 32e29fd95f9cfd42
#
# ********* Entry # 7
# {'company': 'Jobspring Partners', 'state': 'IL', 'jobtitle': 'OOP Expert', 'progskills': ['ruby', 'java', 'python', 'c', 'php'], 'country': 'US', 'qualifications': [], 'longitude': -87.62637, 'expertise': [], 'jobkey': '06ac8eb70143ad62', 'date': 'Wed, 08 Mar 2017 21:17:45 GMT', 'degrees': [], 'latitude': 41.87912}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 06ac8eb70143ad62
#
# ********* Entry # 8
# {'company': 'TEKSystems', 'state': 'CA', 'jobtitle': 'Front End Developer', 'progskills': [], 'country': 'US', 'qualifications': [], 'longitude': -122.39982, 'expertise': [], 'jobkey': '15e5790def47ea12', 'date': 'Tue, 09 May 2017 23:05:54 GMT', 'degrees': [], 'latitude': 37.78505}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 15e5790def47ea12
#
# ********* Entry # 9
# {'company': 'Workbridge Associates', 'state': 'CA', 'jobtitle': 'Principal Data Scientist', 'progskills': ['python', 'java'], 'country': 'US', 'qualifications': ['computer science'], 'longitude': -121.89224, 'expertise': ['machine learning', 'robotics'], 'jobkey': 'f0735102e24122d7', 'date': 'Fri, 21 Apr 2017 03:16:16 GMT', 'degrees': ['ms'], 'latitude': 37.33181}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey f0735102e24122d7
#
# ********* Entry # 10
# {'company': 'Stride Search', 'state': 'CA', 'jobtitle': 'Perception Engineer', 'progskills': ['c++', 'ros', 'opencv'], 'country': 'US', 'qualifications': ['computer science'], 'longitude': -122.41758, 'expertise': ['robotics', 'machine learning'], 'jobkey': '3fecae81fbed7c32', 'date': 'Tue, 04 Apr 2017 06:25:44 GMT', 'degrees': ['bs', 'ms', 'phd'], 'latitude': 37.774727}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 3fecae81fbed7c32
#
# ********* Entry # 11
# {'company': 'Modis', 'state': 'CA', 'jobtitle': 'Software Release Coordinator', 'progskills': [], 'country': 'US', 'qualifications': ['physics'], 'longitude': -122.08242, 'expertise': [], 'jobkey': '715af6682190fb6b', 'date': 'Tue, 28 Feb 2017 19:30:26 GMT', 'degrees': ['bs', 'ba'], 'latitude': 37.384617}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 715af6682190fb6b
#
# 150
# ********* Entry # 1
# {'company': 'Audi Canada', 'state': 'CA', 'jobtitle': 'Sr. Technical Product Engineer - Autonomous Driving', 'progskills': [], 'country': 'US', 'qualifications': ['computer science'], 'longitude': -122.27473, 'expertise': ['robotics', 'machine learning'], 'jobkey': '82a9e0df6b10800c', 'date': 'Wed, 15 Feb 2017 02:19:03 GMT', 'degrees': ['bsc', 'phd'], 'latitude': 37.51923}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 82a9e0df6b10800c
#
# ********* Entry # 2
# {'company': 'Mobileye', 'state': 'OH', 'jobtitle': 'Sales Executive', 'progskills': [], 'country': 'US', 'qualifications': [], 'longitude': -82.99451, 'expertise': [], 'jobkey': '05177a5668ea227f', 'date': 'Tue, 16 May 2017 02:14:41 GMT', 'degrees': [], 'latitude': 39.95879}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 05177a5668ea227f
#
# ********* Entry # 3
# {'company': 'Mobileye', 'state': 'CA', 'jobtitle': 'Sales Executive', 'progskills': [], 'country': 'US', 'qualifications': [], 'longitude': -121.48901, 'expertise': [], 'jobkey': '007d5ca4c4bdc749', 'date': 'Tue, 16 May 2017 00:23:51 GMT', 'degrees': [], 'latitude': 38.57967}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 007d5ca4c4bdc749
#
# ********* Entry # 4
# {'company': 'Mobileye', 'state': 'OR', 'jobtitle': 'Sales Executive', 'progskills': [], 'country': 'US', 'qualifications': [], 'longitude': -122.67583, 'expertise': [], 'jobkey': '16ca9cf3203b02fb', 'date': 'Tue, 16 May 2017 00:18:10 GMT', 'degrees': [], 'latitude': 45.521976}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 16ca9cf3203b02fb
#
# ********* Entry # 5
# {'company': 'Drive.ai', 'state': 'CA', 'jobtitle': 'Senior Software Engineer-Tools and Infrastructure', 'progskills': ['tensorflow', 'python', 'ruby', 'java', 'c++'], 'country': 'US', 'qualifications': [], 'longitude': -122.08242, 'expertise': ['autonomous vehicles'], 'jobkey': 'dce8abc4fcc8920a', 'date': 'Fri, 28 Apr 2017 20:03:11 GMT', 'degrees': [], 'latitude': 37.384617}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey dce8abc4fcc8920a
#
# ********* Entry # 6
# {'company': 'NVIDIA', 'state': 'CA', 'jobtitle': 'Deep Learning Software Engineering Manager', 'progskills': ['python', 'c++', 'tensorflow'], 'country': 'US', 'qualifications': ['computer science'], 'longitude': -121.95055, 'expertise': ['autonomous vehicles', 'radar', 'machine learning'], 'jobkey': '32e29fd95f9cfd42', 'date': 'Wed, 22 Mar 2017 04:33:15 GMT', 'degrees': ['masters', 'phd'], 'latitude': 37.35165}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 32e29fd95f9cfd42
#
# ********* Entry # 7
# {'company': 'Jobspring Partners', 'state': 'IL', 'jobtitle': 'OOP Expert', 'progskills': ['ruby', 'java', 'python', 'c', 'php'], 'country': 'US', 'qualifications': [], 'longitude': -87.62637, 'expertise': [], 'jobkey': '06ac8eb70143ad62', 'date': 'Wed, 08 Mar 2017 21:17:45 GMT', 'degrees': [], 'latitude': 41.87912}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 06ac8eb70143ad62
#
# ********* Entry # 8
# {'company': 'TEKSystems', 'state': 'CA', 'jobtitle': 'Front End Developer', 'progskills': [], 'country': 'US', 'qualifications': [], 'longitude': -122.39982, 'expertise': [], 'jobkey': '15e5790def47ea12', 'date': 'Tue, 09 May 2017 23:05:54 GMT', 'degrees': [], 'latitude': 37.78505}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 15e5790def47ea12
#
# ********* Entry # 9
# {'company': 'Workbridge Associates', 'state': 'CA', 'jobtitle': 'Principal Data Scientist', 'progskills': ['python', 'java'], 'country': 'US', 'qualifications': ['computer science'], 'longitude': -121.89224, 'expertise': ['machine learning', 'robotics'], 'jobkey': 'f0735102e24122d7', 'date': 'Fri, 21 Apr 2017 03:16:16 GMT', 'degrees': ['ms'], 'latitude': 37.33181}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey f0735102e24122d7
#
# ********* Entry # 10
# {'company': 'Stride Search', 'state': 'CA', 'jobtitle': 'Perception Engineer', 'progskills': ['c++', 'ros', 'opencv'], 'country': 'US', 'qualifications': ['computer science'], 'longitude': -122.41758, 'expertise': ['robotics', 'machine learning'], 'jobkey': '3fecae81fbed7c32', 'date': 'Tue, 04 Apr 2017 06:25:44 GMT', 'degrees': ['bs', 'ms', 'phd'], 'latitude': 37.774727}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 3fecae81fbed7c32
#
# ********* Entry # 11
# {'company': 'Modis', 'state': 'CA', 'jobtitle': 'Software Release Coordinator', 'progskills': [], 'country': 'US', 'qualifications': ['physics'], 'longitude': -122.08242, 'expertise': [], 'jobkey': '715af6682190fb6b', 'date': 'Tue, 28 Feb 2017 19:30:26 GMT', 'degrees': ['bs', 'ba'], 'latitude': 37.384617}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 715af6682190fb6b
#
# 175
# ********* Entry # 1
# {'company': 'Audi Canada', 'state': 'CA', 'jobtitle': 'Sr. Technical Product Engineer - Autonomous Driving', 'progskills': [], 'country': 'US', 'qualifications': ['computer science'], 'longitude': -122.27473, 'expertise': ['robotics', 'machine learning'], 'jobkey': '82a9e0df6b10800c', 'date': 'Wed, 15 Feb 2017 02:19:03 GMT', 'degrees': ['bsc', 'phd'], 'latitude': 37.51923}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 82a9e0df6b10800c
#
# ********* Entry # 2
# {'company': 'Mobileye', 'state': 'OH', 'jobtitle': 'Sales Executive', 'progskills': [], 'country': 'US', 'qualifications': [], 'longitude': -82.99451, 'expertise': [], 'jobkey': '05177a5668ea227f', 'date': 'Tue, 16 May 2017 02:14:41 GMT', 'degrees': [], 'latitude': 39.95879}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 05177a5668ea227f
#
# ********* Entry # 3
# {'company': 'Mobileye', 'state': 'CA', 'jobtitle': 'Sales Executive', 'progskills': [], 'country': 'US', 'qualifications': [], 'longitude': -121.48901, 'expertise': [], 'jobkey': '007d5ca4c4bdc749', 'date': 'Tue, 16 May 2017 00:23:51 GMT', 'degrees': [], 'latitude': 38.57967}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 007d5ca4c4bdc749
#
# ********* Entry # 4
# {'company': 'Mobileye', 'state': 'OR', 'jobtitle': 'Sales Executive', 'progskills': [], 'country': 'US', 'qualifications': [], 'longitude': -122.67583, 'expertise': [], 'jobkey': '16ca9cf3203b02fb', 'date': 'Tue, 16 May 2017 00:18:10 GMT', 'degrees': [], 'latitude': 45.521976}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 16ca9cf3203b02fb
#
# ********* Entry # 5
# {'company': 'Drive.ai', 'state': 'CA', 'jobtitle': 'Senior Software Engineer-Tools and Infrastructure', 'progskills': ['tensorflow', 'python', 'ruby', 'java', 'c++'], 'country': 'US', 'qualifications': [], 'longitude': -122.08242, 'expertise': ['autonomous vehicles'], 'jobkey': 'dce8abc4fcc8920a', 'date': 'Fri, 28 Apr 2017 20:03:11 GMT', 'degrees': [], 'latitude': 37.384617}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey dce8abc4fcc8920a
#
# ********* Entry # 6
# ...
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 3fecae81fbed7c32
#
# ********* Entry # 11
# {'company': 'Modis', 'state': 'CA', 'jobtitle': 'Software Release Coordinator', 'progskills': [], 'country': 'US', 'qualifications': ['physics'], 'longitude': -122.08242, 'expertise': [], 'jobkey': '715af6682190fb6b', 'date': 'Tue, 28 Feb 2017 19:30:26 GMT', 'degrees': ['bs', 'ba'], 'latitude': 37.384617}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 715af6682190fb6b
#
# 1100
# ********* Entry # 1
# {'company': 'Audi Canada', 'state': 'CA', 'jobtitle': 'Sr. Technical Product Engineer - Autonomous Driving', 'progskills': [], 'country': 'US', 'qualifications': ['computer science'], 'longitude': -122.27473, 'expertise': ['robotics', 'machine learning'], 'jobkey': '82a9e0df6b10800c', 'date': 'Wed, 15 Feb 2017 02:19:03 GMT', 'degrees': ['bsc', 'phd'], 'latitude': 37.51923}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 82a9e0df6b10800c
#
# ********* Entry # 2
# {'company': 'Mobileye', 'state': 'OH', 'jobtitle': 'Sales Executive', 'progskills': [], 'country': 'US', 'qualifications': [], 'longitude': -82.99451, 'expertise': [], 'jobkey': '05177a5668ea227f', 'date': 'Tue, 16 May 2017 02:14:41 GMT', 'degrees': [], 'latitude': 39.95879}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 05177a5668ea227f
#
# ********* Entry # 3
# {'company': 'Mobileye', 'state': 'CA', 'jobtitle': 'Sales Executive', 'progskills': [], 'country': 'US', 'qualifications': [], 'longitude': -121.48901, 'expertise': [], 'jobkey': '007d5ca4c4bdc749', 'date': 'Tue, 16 May 2017 00:23:51 GMT', 'degrees': [], 'latitude': 38.57967}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 007d5ca4c4bdc749
#
# ********* Entry # 4
# {'company': 'Mobileye', 'state': 'OR', 'jobtitle': 'Sales Executive', 'progskills': [], 'country': 'US', 'qualifications': [], 'longitude': -122.67583, 'expertise': [], 'jobkey': '16ca9cf3203b02fb', 'date': 'Tue, 16 May 2017 00:18:10 GMT', 'degrees': [], 'latitude': 45.521976}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 16ca9cf3203b02fb
#
# ********* Entry # 5
# {'company': 'Drive.ai', 'state': 'CA', 'jobtitle': 'Senior Software Engineer-Tools and Infrastructure', 'progskills': ['tensorflow', 'python', 'ruby', 'java', 'c++'], 'country': 'US', 'qualifications': [], 'longitude': -122.08242, 'expertise': ['autonomous vehicles'], 'jobkey': 'dce8abc4fcc8920a', 'date': 'Fri, 28 Apr 2017 20:03:11 GMT', 'degrees': [], 'latitude': 37.384617}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey dce8abc4fcc8920a
#
# ********* Entry # 6
# {'company': 'NVIDIA', 'state': 'CA', 'jobtitle': 'Deep Learning Software Engineering Manager', 'progskills': ['python', 'c++', 'tensorflow'], 'country': 'US', 'qualifications': ['computer science'], 'longitude': -121.95055, 'expertise': ['autonomous vehicles', 'radar', 'machine learning'], 'jobkey': '32e29fd95f9cfd42', 'date': 'Wed, 22 Mar 2017 04:33:15 GMT', 'degrees': ['masters', 'phd'], 'latitude': 37.35165}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 32e29fd95f9cfd42
#
# ********* Entry # 7
# {'company': 'Jobspring Partners', 'state': 'IL', 'jobtitle': 'OOP Expert', 'progskills': ['ruby', 'java', 'python', 'c', 'php'], 'country': 'US', 'qualifications': [], 'longitude': -87.62637, 'expertise': [], 'jobkey': '06ac8eb70143ad62', 'date': 'Wed, 08 Mar 2017 21:17:45 GMT', 'degrees': [], 'latitude': 41.87912}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 06ac8eb70143ad62
#
# ********* Entry # 8
# {'company': 'TEKSystems', 'state': 'CA', 'jobtitle': 'Front End Developer', 'progskills': [], 'country': 'US', 'qualifications': [], 'longitude': -122.39982, 'expertise': [], 'jobkey': '15e5790def47ea12', 'date': 'Tue, 09 May 2017 23:05:54 GMT', 'degrees': [], 'latitude': 37.78505}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 15e5790def47ea12
#
# ********* Entry # 9
# {'company': 'Workbridge Associates', 'state': 'CA', 'jobtitle': 'Principal Data Scientist', 'progskills': ['python', 'java'], 'country': 'US', 'qualifications': ['computer science'], 'longitude': -121.89224, 'expertise': ['machine learning', 'robotics'], 'jobkey': 'f0735102e24122d7', 'date': 'Fri, 21 Apr 2017 03:16:16 GMT', 'degrees': ['ms'], 'latitude': 37.33181}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey f0735102e24122d7
#
# ********* Entry # 10
# {'company': 'Stride Search', 'state': 'CA', 'jobtitle': 'Perception Engineer', 'progskills': ['c++', 'ros', 'opencv'], 'country': 'US', 'qualifications': ['computer science'], 'longitude': -122.41758, 'expertise': ['robotics', 'machine learning'], 'jobkey': '3fecae81fbed7c32', 'date': 'Tue, 04 Apr 2017 06:25:44 GMT', 'degrees': ['bs', 'ms', 'phd'], 'latitude': 37.774727}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 3fecae81fbed7c32
#
# ********* Entry # 11
# {'company': 'Modis', 'state': 'CA', 'jobtitle': 'Software Release Coordinator', 'progskills': [], 'country': 'US', 'qualifications': ['physics'], 'longitude': -122.08242, 'expertise': [], 'jobkey': '715af6682190fb6b', 'date': 'Tue, 28 Feb 2017 19:30:26 GMT', 'degrees': ['bs', 'ba'], 'latitude': 37.384617}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 715af6682190fb6b
#
# 1125
# ********* Entry # 1
# {'company': 'Audi Canada', 'state': 'CA', 'jobtitle': 'Sr. Technical Product Engineer - Autonomous Driving', 'progskills': [], 'country': 'US', 'qualifications': ['computer science'], 'longitude': -122.27473, 'expertise': ['robotics', 'machine learning'], 'jobkey': '82a9e0df6b10800c', 'date': 'Wed, 15 Feb 2017 02:19:03 GMT', 'degrees': ['bsc', 'phd'], 'latitude': 37.51923}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 82a9e0df6b10800c
#
# ********* Entry # 2
# {'company': 'Mobileye', 'state': 'OH', 'jobtitle': 'Sales Executive', 'progskills': [], 'country': 'US', 'qualifications': [], 'longitude': -82.99451, 'expertise': [], 'jobkey': '05177a5668ea227f', 'date': 'Tue, 16 May 2017 02:14:41 GMT', 'degrees': [], 'latitude': 39.95879}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 05177a5668ea227f
#
# ********* Entry # 3
# {'company': 'Mobileye', 'state': 'CA', 'jobtitle': 'Sales Executive', 'progskills': [], 'country': 'US', 'qualifications': [], 'longitude': -121.48901, 'expertise': [], 'jobkey': '007d5ca4c4bdc749', 'date': 'Tue, 16 May 2017 00:23:51 GMT', 'degrees': [], 'latitude': 38.57967}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 007d5ca4c4bdc749
#
# ********* Entry # 4
# {'company': 'Mobileye', 'state': 'OR', 'jobtitle': 'Sales Executive', 'progskills': [], 'country': 'US', 'qualifications': [], 'longitude': -122.67583, 'expertise': [], 'jobkey': '16ca9cf3203b02fb', 'date': 'Tue, 16 May 2017 00:18:10 GMT', 'degrees': [], 'latitude': 45.521976}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 16ca9cf3203b02fb
#
# ********* Entry # 5
# {'company': 'Drive.ai', 'state': 'CA', 'jobtitle': 'Senior Software Engineer-Tools and Infrastructure', 'progskills': ['tensorflow', 'python', 'ruby', 'java', 'c++'], 'country': 'US', 'qualifications': [], 'longitude': -122.08242, 'expertise': ['autonomous vehicles'], 'jobkey': 'dce8abc4fcc8920a', 'date': 'Fri, 28 Apr 2017 20:03:11 GMT', 'degrees': [], 'latitude': 37.384617}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey dce8abc4fcc8920a
#
# ********* Entry # 6
# {'company': 'NVIDIA', 'state': 'CA', 'jobtitle': 'Deep Learning Software Engineering Manager', 'progskills': ['python', 'c++', 'tensorflow'], 'country': 'US', 'qualifications': ['computer science'], 'longitude': -121.95055, 'expertise': ['autonomous vehicles', 'radar', 'machine learning'], 'jobkey': '32e29fd95f9cfd42', 'date': 'Wed, 22 Mar 2017 04:33:15 GMT', 'degrees': ['masters', 'phd'], 'latitude': 37.35165}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 32e29fd95f9cfd42
#
# ********* Entry # 7
# {'company': 'Jobspring Partners', 'state': 'IL', 'jobtitle': 'OOP Expert', 'progskills': ['ruby', 'java', 'python', 'c', 'php'], 'country': 'US', 'qualifications': [], 'longitude': -87.62637, 'expertise': [], 'jobkey': '06ac8eb70143ad62', 'date': 'Wed, 08 Mar 2017 21:17:45 GMT', 'degrees': [], 'latitude': 41.87912}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 06ac8eb70143ad62
#
# ********* Entry # 8
# {'company': 'TEKSystems', 'state': 'CA', 'jobtitle': 'Front End Developer', 'progskills': [], 'country': 'US', 'qualifications': [], 'longitude': -122.39982, 'expertise': [], 'jobkey': '15e5790def47ea12', 'date': 'Tue, 09 May 2017 23:05:54 GMT', 'degrees': [], 'latitude': 37.78505}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 15e5790def47ea12
#
# ********* Entry # 9
# {'company': 'Workbridge Associates', 'state': 'CA', 'jobtitle': 'Principal Data Scientist', 'progskills': ['python', 'java'], 'country': 'US', 'qualifications': ['computer science'], 'longitude': -121.89224, 'expertise': ['machine learning', 'robotics'], 'jobkey': 'f0735102e24122d7', 'date': 'Fri, 21 Apr 2017 03:16:16 GMT', 'degrees': ['ms'], 'latitude': 37.33181}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey f0735102e24122d7
#
# ********* Entry # 10
# {'company': 'Stride Search', 'state': 'CA', 'jobtitle': 'Perception Engineer', 'progskills': ['c++', 'ros', 'opencv'], 'country': 'US', 'qualifications': ['computer science'], 'longitude': -122.41758, 'expertise': ['robotics', 'machine learning'], 'jobkey': '3fecae81fbed7c32', 'date': 'Tue, 04 Apr 2017 06:25:44 GMT', 'degrees': ['bs', 'ms', 'phd'], 'latitude': 37.774727}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 3fecae81fbed7c32
#
# ********* Entry # 11
# {'company': 'Modis', 'state': 'CA', 'jobtitle': 'Software Release Coordinator', 'progskills': [], 'country': 'US', 'qualifications': ['physics'], 'longitude': -122.08242, 'expertise': [], 'jobkey': '715af6682190fb6b', 'date': 'Tue, 28 Feb 2017 19:30:26 GMT', 'degrees': ['bs', 'ba'], 'latitude': 37.384617}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 715af6682190fb6b
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, **httplib_request_kw)
#     392             try: # Python 2.7+, use buffering of HTTP responses
# --> 393                 httplib_response = conn.getresponse(buffering=True)
#     394             except TypeError: # Python 2.6 and older
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-b467d418ac6f> in <module>()
#      26
#      27 #
# ---> 28 jobsScrap.record(keywords, start, limit)
#
# <ipython-input-11-428cb9d3a629> in record(self, keywords, start, limit)
#     219         while len(self.tracker) < self.thres:
#     220             #get more responses (pagination)
# --> 221             query_response = self.get_jobsListing(keywords, start, limit)
#     222             n_entry = 0
#     223             print(start)
#
# <ipython-input-11-428cb9d3a629> in get_jobsListing(self, keywords, start, limit)
#     138                      }
#     139
# --> 140             return client.search(**params)
#     141         else:
#     142             return []
#
# /usr/local/lib/python3.5/dist-packages/indeed/__init__.py in search(self, **args)
#      15
#      16     def search(self, **args):
# ---> 17         return self.__process_request(API_SEARCH.get('end_point'), self.__valid_args(API_SEARCH.get('required_fields'), args))
#      18
#      19     def jobs(self, **args):
#
# /usr/local/lib/python3.5/dist-packages/indeed/__init__.py in __process_request(self, endpoint, args)
#      26         raw = True if format == 'xml' else args.get('raw', False)
#      27         args.update({'v': self.version, 'publisher': self.publisher, 'format': format})
# ---> 28         r = requests.get(endpoint, params = args)
#      29         return r.json() if not raw else r.content
#      30
#
# /usr/local/lib/python3.5/dist-packages/requests/api.py in get(url, **kwargs)
#      53
#      54     kwargs.setdefault('allow_redirects', True)
# ---> 55     return request('get', url, **kwargs)
#      56
#      57
#
# /usr/local/lib/python3.5/dist-packages/requests/api.py in request(method, url, **kwargs)
#      42
#      43     session = sessions.Session()
# ---> 44     return session.request(method=method, url=url, **kwargs)
#      45
#      46
#
# /usr/local/lib/python3.5/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert)
#     355             'allow_redirects': allow_redirects,
#     356         }
# --> 357         resp = self.send(prep, **send_kwargs)
#     358
#     359         return resp
#
# /usr/local/lib/python3.5/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     458         start = datetime.utcnow()
#     459         # Send the request
# --> 460         r = adapter.send(request, **kwargs)
#     461         # Total elapsed time of the request (approximately)
#     462         r.elapsed = datetime.utcnow() - start
#
# /usr/local/lib/python3.5/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     317                     decode_content=False,
#     318                     retries=self.max_retries,
# --> 319                     timeout=timeout
#     320                 )
#     321
#
# /usr/local/lib/python3.5/dist-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, **response_kw)
#     539             httplib_response = self._make_request(conn, method, url,
#     540                                                   timeout=timeout,
# --> 541                                                   body=body, headers=headers)
#     542
#     543             # If we're going to release the connection in ``finally:``, then
#
# /usr/local/lib/python3.5/dist-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, **httplib_request_kw)
#     393                 httplib_response = conn.getresponse(buffering=True)
#     394             except TypeError: # Python 2.6 and older
# --> 395                 httplib_response = conn.getresponse()
#     396         except SocketTimeout:
#     397             raise ReadTimeoutError(
#
# /usr/lib/python3.5/http/client.py in getresponse(self)
#    1195         try:
#    1196             try:
# -> 1197                 response.begin()
#    1198             except ConnectionError:
#    1199                 self.close()
#
# /usr/lib/python3.5/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /usr/lib/python3.5/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /usr/lib/python3.5/socket.py in readinto(self, b)
#     573         while True:
#     574             try:
# --> 575                 return self._sock.recv_into(b)
#     576             except timeout:
#     577                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
a500e830f882fa33
0a721111b17a11bd
425d0adc79549f84
5147236854f820cc
7642b903941ba383
d98a8ba272160199
16a35b3f70d6d95b
9c3af2082fd931a1
9b48faba1ee2be4b
081546d6a61cbf14
eb0a567f297ac543
2f6ea160772724fa
a190c2489c94713d
beabca6a62cadb18
da62fbd34905e2f3
3b6ad44d98e65177
69fc6eab546f0c07
9bd5f8e79a9e6326
864e3cbc1d533e67
810d540fa80ab75b
fe5d3173d3c2e9d7
cdf0e6b3e2ea340d
f77b1624f6efaecf
d861972a4e1ec72d
7242d2755bfc7e1f
"671f5ef33e752ea5"
"dfedf15956e817f1"
"64b6b989b460e90e"
"9c936f747be81b57"
"206962c96e02c5c1"
"2925af331146a975"
"1d58a55397f7e4d7"

"b20328007c9b07f6"
"f231a533b2d1b86b"
"3388c3ea2bcf9052"
"e9948beeb240fe3d"
"a554ac5e169ab57c"
"efdc7294c9bf505f"
"bc4a9a8247ad5f1f"
"5d66ffc28875bb87"
"7c83793108ca8ed0"
"7acad51c841caed5"
"da9d9dee5bdfaed9"
"93812cc5ad371e3d"
"7e97960b95920ca5"
"3c9d946391d7fa83"
"1e71d0ce5f03d77e"
"1bae21618de91938"
"94c6bdba144cce70"
"6b3526201b7f16ae"
"9fb9e1b3bc69b7fb"
"155743d40d115331"
"724ba2731572c639"
"de7fee13ac142b03"
"2d8f948af9681772"
"d1f6fd292ea60843"
"16aab02b7c66f836"
"49d85899900bab1b"
"50d9598e6263200f"
"158d70b48e3eb608"
"a9892af685c0ad1a"

# %%
conn = sqlite3.connect('indeed.db')
c = conn.cursor()
#select in jobs all unique values in column = employer

#k = [19e116b3b8b9142d, c8acfe28f5b7c2a5, 141de5c6bb03a6f7, b93cb63a881d1962, 0af5d1b6f3087803, 34818bd8f9c2fb24,
#       37ed6d5935e4b254, fb174186f27a53e8, 59468e265a77a81c, 634e159a2a6d0a87, 7a8b66aea2d4c851, d2f8ca044e51e65a, 
#        e0071062ac7070b9, e94f6e213ea5160b]

sql_manager = "SELECT jobkey FROM jobs WHERE jobkey='a9892af685c0ad1a';"
c.execute(sql_manager)
result = c.fetchall()
print(len(result))
for jk in result:
    jk = jk[0]
    try:
        sql_delete = "DELETE FROM jobs WHERE jobkey='{}';".format(jk)
        c.execute(sql_delete)
        conn.commit()
    except:
        print('could not delete {} from table: jobs')

    try:
        sql_delete = "DELETE FROM degrees WHERE jobkey='{}';".format(jk)
        c.execute(sql_delete)
        conn.commit()
    except:
        print('could not delete {} from table: degrees')    
    try:
        sql_delete = "DELETE FROM expertise WHERE jobkey='{}';".format(jk)
        c.execute(sql_delete)
        conn.commit()
    except:
        print('could not delete {} from table: expertise')
    try:
        sql_delete = "DELETE FROM progskills WHERE jobkey='{}';".format(jk)
        c.execute(sql_delete)
        conn.commit()
    except:
        print('could not delete {} from table: progskills')
    try:
        sql_delete = "DELETE FROM qualifications WHERE jobkey='{}';".format(jk)
        c.execute(sql_delete)
        conn.commit()
    except:
        print('could not delete {} from table: qualifications')
c.execute(sql_manager)
result = c.fetchall()
# Out:
# 1

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt


conn = sqlite3.connect('indeed.db')
c = conn.cursor()
#select in jobs all unique values in column = employer
sql_manager = "SELECT * FROM jobs;"
c.execute(sql_manager)
result = c.fetchall()
print(len(result))
data_pts = []        
for entry in result:
    data_pts.append([entry[6], entry[7]])

def mapTut(pts):

    m = Basemap(projection='mill',llcrnrlat=20,urcrnrlat=50,\
                llcrnrlon=-130,urcrnrlon=-60,resolution='c')
    m.bluemarble()
    m.drawcoastlines()
    m.drawcountries(linewidth=2)
    m.drawstates()
    #m.fillcontinents(color='#04BAE3',lake_color='#FFFFFF')
    m.drawmapboundary(fill_color='#FFFFFF')

    for point in pts:
        if len(point[0] ) > 0:
            lat, lon = float(point[1]), float(point[0])
            x,y = m(lon,lat)
            m.plot(x,y, 'ro')
   
    # Houston, Texas


    
    plt.title("Geo Plotting")
    plt.show()


mapTut(data_pts)
# Out:
# 1005

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
from matplotlib.patches import Polygon

# create the map
map = Basemap(llcrnrlon=-119,llcrnrlat=22,urcrnrlon=-64,urcrnrlat=49,
        projection='lcc',lat_1=33,lat_2=45,lon_0=-95)

# load the shapefile, use the name 'states'
map.readshapefile('st99_d00', name='states', drawbounds=True)

# collect the state names from the shapefile attributes so we can
# look up the shape obect for a state by it's name
state_names = []
for shape_dict in map.states_info:
    state_names.append(shape_dict['NAME'])

ax = plt.gca() # get current axes instance

# get Texas and draw the filled polygon
seg = map.states[state_names.index('Texas')]
poly = Polygon(seg, facecolor='red',edgecolor='red')
ax.add_patch(poly)

plt.show()
