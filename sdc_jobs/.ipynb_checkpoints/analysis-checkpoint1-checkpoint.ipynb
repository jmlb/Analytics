# %% [markdown]
# # Mapping jobs location

# %%
from indeed import IndeedClient
from mpl_toolkits.basemap import Basemap
import sqlite3
from time import sleep # To prevent overwhelming the server between connections
import pandas as pd # For converting results to a dataframe and bar chart plots
from matplotlib.patches import Polygon
from matplotlib.colors import rgb2hex
import matplotlib as mpl
import numpy as np
import operator
import matplotlib.pyplot as plt
from prettytable import PrettyTable

cmap= plt.cm.Blues
# %matplotlib inline
client = IndeedClient(publisher ="9124561496937265")


short_state_names = {
        'AK': 'Alaska',
        'AL': 'Alabama',
        'AR': 'Arkansas',
        'AS': 'American Samoa',
        'AZ': 'Arizona',
        'CA': 'California',
        'CO': 'Colorado',
        'CT': 'Connecticut',
        'DC': 'District of Columbia',
        'DE': 'Delaware',
        'FL': 'Florida',
        'GA': 'Georgia',
        'GU': 'Guam',
        'HI': 'Hawaii',
        'IA': 'Iowa',
        'ID': 'Idaho',
        'IL': 'Illinois',
        'IN': 'Indiana',
        'KS': 'Kansas',
        'KY': 'Kentucky',
        'LA': 'Louisiana',
        'MA': 'Massachusetts',
        'MD': 'Maryland',
        'ME': 'Maine',
        'MI': 'Michigan',
        'MN': 'Minnesota',
        'MO': 'Missouri',
        'MP': 'Northern Mariana Islands',
        'MS': 'Mississippi',
        'MT': 'Montana',
        'NA': 'National',
        'NC': 'North Carolina',
        'ND': 'North Dakota',
        'NE': 'Nebraska',
        'NH': 'New Hampshire',
        'NJ': 'New Jersey',
        'NM': 'New Mexico',
        'NV': 'Nevada',
        'NY': 'New York',
        'OH': 'Ohio',
        'OK': 'Oklahoma',
        'OR': 'Oregon',
        'PA': 'Pennsylvania',
        'PR': 'Puerto Rico',
        'RI': 'Rhode Island',
        'SC': 'South Carolina',
        'SD': 'South Dakota',
        'TN': 'Tennessee',
        'TX': 'Texas',
        'UT': 'Utah',
        'VA': 'Virginia',
        'VI': 'Virgin Islands',
        'VT': 'Vermont',
        'WA': 'Washington',
        'WI': 'Wisconsin',
        'WV': 'West Virginia',
        'WY': 'Wyoming'
}

# %%
conn = sqlite3.connect('indeed.db')
c = conn.cursor()
#select in jobs all unique values in column = employer
sql_manager = "SELECT * FROM jobs;"
c.execute(sql_manager)
result = c.fetchall()
print(len(result))
data_pts = []        
for entry in result:
    data_pts.append([entry[6], entry[7]])

def mapTut(pts):

    m = Basemap(projection='mill',llcrnrlat=20,urcrnrlat=50,\
                llcrnrlon=-130,urcrnrlon=-60,resolution='c')
    m.bluemarble()
    m.drawcoastlines()
    m.drawcountries(linewidth=2)
    m.drawstates()
    #m.fillcontinents(color='#04BAE3',lake_color='#FFFFFF')
    m.drawmapboundary(fill_color='#FFFFFF')

    for point in pts:
        if len(point[0] ) > 0:
            lat, lon = float(point[1]), float(point[0])
            x,y = m(lon,lat)
            m.plot(x,y, 'ro')
   
    # Houston, Texas


    
    plt.title("Geo Plotting")
    plt.show()


mapTut(data_pts)
# Out:
# 765
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-d936273fdaa8> in <module>()
#      34
#      35
# ---> 36 mapTut(data_pts)
#
# <ipython-input-3-d936273fdaa8> in mapTut(pts)
#      22     for point in pts:
#      23         if len(point[0] ) > 0:
# ---> 24             lat, lon = float(point[1]), float(point[0])
#      25             x,y = m(lon,lat)
#      26             m.plot(x,y, 'ro')
#
# ValueError: could not convert string to float: '\u200e37.368832'

# %%
################################
# Get data - select data from db
###############################
sql_all_jobs = "SELECT jobkey, state FROM jobs;"
c.execute(sql_all_jobs)
all_jobs = c.fetchall()
total_nb_jobs = len(all_jobs)
#create a dict with count of jobs per state
jobs_in_state = {}

for job_entry in all_jobs:
    this_state = job_entry[1]
    #this_jobkey = job_entry[0]
    if len(this_state) > 0:
        long_name = short_state_names[this_state]
        if long_name in jobs_in_state:
            jobs_in_state[long_name] += 1
        else:
            jobs_in_state[long_name] = 1
        
# Need max and min value to normalize the colorbar
state_max =  max(jobs_in_state, key=jobs_in_state.get)
state_min =  min(jobs_in_state, key=jobs_in_state.get)
max_jobs = jobs_in_state[state_max]
min_jobs = jobs_in_state[state_min]
job_density_max = 1-(total_nb_jobs - max_jobs)*1.0/(total_nb_jobs)

# create the map
fig, ax = plt.subplots(figsize=(16,8))
map = Basemap(llcrnrlon=-119,llcrnrlat=22,urcrnrlon=-64,urcrnrlat=49,
        projection='lcc',lat_1=33,lat_2=45,lon_0=-95)
# load the shapefile, use the name 'states'
map.readshapefile('st99_d00', name='states', drawbounds=True)

state_names = []
for shape_dict in map.states_info:
    state_names.append(shape_dict['NAME'])



for this_state in jobs_in_state:
    #Calculate statistics
    nb_jobs = jobs_in_state[this_state]
    ax = plt.gca() # get current axes instance
    # get state_name and draw the filled polygon
    seg = map.states[state_names.index(this_state)]
    job_density = 1-(total_nb_jobs - nb_jobs)*1.0/(total_nb_jobs)
    normalized_alpha = job_density / (job_density_max)
    #poly = Polygon(seg, facecolor='#1B4F72', alpha=normalized_alpha)
    poly = Polygon(seg, facecolor=cmap(normalized_alpha)) 
    ax.add_patch(poly)

# Make an axis for the colorbar on the right side

norm = mpl.colors.Normalize(vmin=0, vmax=0.5)
cmap = plt.cm.Blues
cax = fig.add_axes([0.95, 0.2, 0.02, 0.6])
cb = mpl.colorbar.ColorbarBase(cax, cmap=cmap, norm=norm, spacing='proportional')


plt.title('SDC job postings per States (pct)')
plt.show()

# %%
#### Plot number of jobs per state
####################################
show_n_largest = 10 #

def get_xaxis_labels(y_pt, all_data, ls_states):
    """
    Attach a text label above each bar displaying its height
    """
    txt_labels = ''
    for state in all_data:
        if all_data[state] == y_pt:
            state_abrev = list(ls_states.keys())[list(ls_states.values()).index(state)]
            txt_labels = state_abrev+' '+txt_labels
    return txt_labels


job_cnts = []
for item in jobs_in_state:
    job_cnts.append(jobs_in_state[item])
#sort the unique counts
sorted_job_cnts = sorted(set(job_cnts), reverse=True)
#exception: 
if show_n_largest > len(sorted_job_cnts):
    show_n_largest = len(sorted_job_cnts)
x = np.arange(0, show_n_largest, 1)
fig, ax = plt.subplots(figsize=(12,6))
rects1 = ax.bar(x, sorted_job_cnts[0:show_n_largest], color='b')
# add some text for labels, title and axes ticks
ax.set_ylabel('Number of job openings', fontsize=18)
ax.set_title('States with largest number of SDC job openings', fontsize=18)
xticklabels = []
for y_pt in sorted_job_cnts[0:show_n_largest]:
    x_label = get_xaxis_labels(y_pt, jobs_in_state, short_state_names)
    xticklabels.append(x_label)  
#ax.set_xticklabels(xticklabels, rotation='vertical')
plt.xticks(x, xticklabels, fontsize=18)
ax.tick_params(axis='y', labelsize=14)
#tick.label.set_fontsize(14) 
#autolabel(rects1)


plt.show()

# %% [markdown]
#  # List of automotive assembly plants in the United States
#
#
#  https://en.wikipedia.org/wiki/List_of_automotive_assembly_plants_in_the_United_States

# %%
data_us_plants = {'GM': ['Texas', 'Kentucky', 'Michigan', 'Kansas', 'Michigan', 'Indiana', 'Michigan', 'Ohio',
                        'Tennessee', 'Missouri'],
                  'Ford Motor Company': ['Michigan', 'Illinois', 'Michigan', 'Missouri', 'Kentucky', 'Kentucky',
                  'Michigan', 'Ohio'],
                  'Fiat Chrysler': ['Illinois', 'Michigan', 'Michigan', 'Ohio', 'Michigan'],
                  'Tesla': ['California'],
                  'AM General': ['Indiana'],
                  'Toyota Motor Corporation': ['Kentucky', 'Indiana', 'Texas', 'Mississippi'],
                  'Honda': ['Ohio', 'Ohio', 'Alabama', 'Indiana', 'Indiana'],
                  'Nissan': ['Tennessee', 'Mississippi'],
                  'Fuji Heavy Industries': ['Indiana'],
                  'Volkswagen': ['Tennessee'],
                  'Hyundai Motor': ['Alabama'],
                  'Kia Motors': ['Georgia'],
                  'BMW Group': ['South Carolina'],
                  'Daimler': ['Alabama', 'South Carolina']
                  }


##########
# Build dictionary of plant state density per state
###############################
plants_location = {}
total_nb_plants = 0
for brand in data_us_plants:
    for this_state in data_us_plants[brand]:
        total_nb_plants += 1
        if this_state in plants_location:
            plants_location[this_state] += 1
        else:
            plants_location[this_state] = 1

print(plants_location)          
# Need max and min value to normalize the colorbar
state_max =  max(plants_location, key=plants_location.get)
state_min =  min(plants_location, key=plants_location.get)
max_plants = plants_location[state_max]
min_plants = plants_location[state_min]
plant_density_max = 1-(total_nb_plants - max_plants)*1.0/(total_nb_plants)


# create the map
fig, ax = plt.subplots(figsize=(16,8))
map = Basemap(llcrnrlon=-119,llcrnrlat=22,urcrnrlon=-64,urcrnrlat=49,
        projection='lcc',lat_1=33,lat_2=45,lon_0=-95)
# load the shapefile, use the name 'states'
map.readshapefile('st99_d00', name='states', drawbounds=True)
for this_state in plants_location:
    #Calculate statistics
    nb_plants = plants_location[this_state]
    ax = plt.gca() # get current axes instance
    # get Texas and draw the filled polygon
    seg = map.states[state_names.index(this_state)]
    plant_density = 1-(total_nb_plants - nb_plants)*1.0/(total_nb_plants)
    normalized_alpha = plant_density / (plant_density_max)
    #poly = Polygon(seg, facecolor='#1B4F72', alpha=normalized_alpha)
    poly = Polygon(seg, facecolor=cmap(norm(normalized_alpha)) )
    ax.add_patch(poly)

# Make an axis for the colorbar on the right side

norm = mpl.colors.Normalize(vmin=0, vmax=0.5)
cmap = plt.cm.Blues
cax = fig.add_axes([0.95, 0.2, 0.02, 0.6])
cb = mpl.colorbar.ColorbarBase(cax, cmap=cmap, norm=norm, spacing='proportional')


plt.title('Car Assembly plants per states (pct)')
plt.show()
# Out:
# {'Ohio': 5, 'Mississippi': 2, 'Texas': 2, 'Indiana': 6, 'Kentucky': 4, 'Kansas': 1, 'Georgia': 1, 'South Carolina': 2, 'Missouri': 2, 'Alabama': 3, 'Michigan': 9, 'California': 1, 'Illinois': 2, 'Tennessee': 3}

# %% [markdown]
# # WHO IS HIRING?

# %%
conn = sqlite3.connect('indeed.db')
c = conn.cursor()
#select in jobs all unique values in column = employer
sql_manager = "SELECT jobkey, employer FROM jobs;"
c.execute(sql_manager)
result = c.fetchall()

employers = {}

for this_job in result:
    this_jobkey = this_job[0]
    employer = this_job[1]
    #make sure the extracted employer name is not empty
    if len(employer) > 0:
        if employer in employers:
            employers[employer] += 1
        else:
            employers[employer] = 1


print('Total Nbr of companies {}'.format(len(employers)) )

x = PrettyTable(["Company Name", "Nbr of job postings"]) 
for employer in employers: 
    x.add_row([employer, employers[employer]])

print(x);
# Out:
# Total Nbr of companies 229
# +----------------------------------------------+---------------------+
# |                 Company Name                 | Nbr of job postings |
# +----------------------------------------------+---------------------+
# |                  CivilMaps                   |          4          |
# |             Booz Allen Hamilton              |          1          |
# |                    Delphi                    |          15         |
# |            ISP Optics Corporation            |          3          |
# |                Stride Search                 |          7          |
# |                 Rand McNally                 |          1          |
# |                    Zemax                     |          1          |
# |                    Optech                    |          1          |
# |            Real-Time Innovations             |          7          |
# |              Polaris Industries              |          1          |
# |                    RGBSI                     |          1          |
# |              GlobalLogic, Inc.               |          1          |
# |                    Google                    |          17         |
# |                    NVIDIA                    |          31         |
# |                   Echodyne                   |          1          |
# |                   TuSimple                   |          4          |
# |             Kemper America, Inc.             |          1          |
# |                TORC Robotics                 |          8          |
# |                   Tesloop                    |          3          |
# |        Ukpeagvik Iñupiat Corporation         |          1          |
# |           Apollo Video Technology            |          1          |
# |                   Transdev                   |          1          |
# |            Atlanta Public Schools            |          1          |
# |               RFA Engineering                |          2          |
# |             Raag Solutions .LLC              |          1          |
# |      Volkswagen Group of America, Inc.       |          2          |
# |                 Lucid Motors                 |          9          |
# |            Aurora Flight Sciences            |          2          |
# |          Thales Communications, Inc          |          1          |
# |        General Dynamics Land Systems         |          2          |
# |             Amazon Robotics LLC              |          1          |
# |            G-TECH Services, Inc.             |          1          |
# |     The Investment Fund For Foundations      |          1          |
# |                  Danlaw Inc                  |          1          |
# |           MOBIS NORTH AMERICA, LLC           |          2          |
# | The Johns Hopkins Applied Physics Laboratory |          2          |
# |                Dart Container                |          1          |
# |                Synopsys, Inc.                |          1          |
# |               Raytheon Canada                |          3          |
# |            Intellipro Group Inc.             |          2          |
# |                    ANSYS                     |          1          |
# |       Federal Aviation Administration        |          1          |
# |  Hitachi Automotive Systems Americas, Inc.   |          1          |
# |            Texas A&M Engineering             |          1          |
# |                  Oculus VR                   |          1          |
# |                     ISO                      |          1          |
# |                    Modis                     |          2          |
# |       SMYTH COUNTY COMMUNITY HOSPITAL        |          1          |
# |                   nuTonomy                   |          7          |
# |      Technical Professionals Group, LLC      |          2          |
# |           SmartDrive Systems, Inc.           |          2          |
# |               TE Connectivity                |          1          |
# |            National Career Group             |          1          |
# |           Robroy Industries, Inc.            |          1          |
# |                   Dispatch                   |          2          |
# |                Kite Staffing                 |          1          |
# |                    INRIX                     |          1          |
# |          Amazon Web Services, Inc.           |          1          |
# |     Woods Hole Oceanographic Institution     |          1          |
# |                 Bosch Group                  |          3          |
# |         Samsung Semiconductor, Inc.          |          3          |
# |             Oshkosh Corporation              |          1          |
# |                 Vertisystem                  |          1          |
# |          Jet Propulsion Laboratory           |          3          |
# |                   Samsung                    |          1          |
# |              Roush Enterprises               |          4          |
# |             AeroVironment, Inc.              |          1          |
# |               Blue Origin, LLC               |          1          |
# |                Pratt & Miller                |          1          |
# |                    Arrivo                    |          1          |
# |                 Trimble Inc.                 |          2          |
# |                  Improbable                  |          1          |
# |               Dura Automotive                |          2          |
# |        Nalco Water, An Ecolab Company        |          4          |
# |         Samsung Electronics America          |          1          |
# |            Elektrobit Automotive             |          1          |
# |             Visteon Corporation              |          4          |
# |            Liquid Robotics, Inc.             |          3          |
# |                 Fast Switch                  |          1          |
# |                  Optimetra                   |          1          |
# |                 Metron, Inc.                 |          2          |
# |        Roy Jorgensen Associates, Inc.        |          1          |
# |                   Progeny                    |          1          |
# |                   Textron                    |          1          |
# |                  Brightwing                  |          1          |
# |            C2S Technologies, Inc             |          1          |
# |                General Motors                |          20         |
# |                 Embark Drive                 |          1          |
# |              The Creative Group              |          1          |
# |                 Reliance One                 |          1          |
# |                Onward Search                 |          2          |
# |              Peloton Technology              |          4          |
# |             The Ulven Companies              |          1          |
# |          National Career Group, LLC          |          2          |
# |              Dealer Specialties              |          2          |
# |                     MIT                      |          1          |
# |               StratiFi Health                |          1          |
# |                     SGT                      |          1          |
# |                 MSC Software                 |          1          |
# |             Texas A&M University             |          4          |
# | Kennedy Unlimited Inc, Professional Staffing |          1          |
# |               Tennant Company                |          1          |
# |            Physical Sciences Inc.            |          1          |
# |                AM General LLC                |          1          |
# |                   Quanergy                   |          1          |
# |                  Logyx, LLC                  |          1          |
# |             Stride Talent Ageny              |          1          |
# |                Ricardo, Inc.                 |          1          |
# |           North American Lighting            |          1          |
# |                  MWI Pumps                   |          1          |
# |                  TrueMotion                  |          1          |
# |              CANVAS Technology               |          2          |
# |                    Toyota                    |          1          |
# |                    Jacobs                    |          1          |
# |          The Aerospace Corporation           |          1          |
# |            Penn State University             |          2          |
# |      NALCO Champion, An Ecolab Company       |          5          |
# |              Jobspring Partners              |          8          |
# |              SAE International               |          1          |
# |            Infineon Technologies             |          1          |
# |                   DCS Corp                   |          1          |
# |                  smartdrive                  |          2          |
# |                   Hydroid                    |          8          |
# |                  SF Motors                   |          2          |
# |                 Symbotic LLC                 |          1          |
# |             Romanoff Renovations             |          2          |
# |          Summit Automotive Partners          |          1          |
# |                    Leidos                    |          2          |
# |                   Argo AI                    |          11         |
# |             Faraday Future, Inc.             |          4          |
# |                 Autoliv Inc.                 |          1          |
# |                    Eaton                     |          3          |
# |                 BAE Systems                  |          3          |
# |                    SpaceX                    |          3          |
# |                    Nauto                     |          9          |
# |                    Bosch                     |          6          |
# |            PARC, a Xerox company             |          1          |
# |                    3coast                    |          1          |
# |                     Uber                     |          12         |
# |                FCA Group LLC                 |          3          |
# |          Sierra Nevada Corporation           |          1          |
# |                  Honeywell                   |          1          |
# |                     HERE                     |          25         |
# |                Volvo Car USA                 |          1          |
# |    Metropolitan Transportation Authority     |          1          |
# |                     AVL                      |          2          |
# |                    Intel                     |          9          |
# |               Lockheed Martin                |          8          |
# |                 Oceaneering                  |          4          |
# |          Mandli Communications Inc           |          1          |
# |              Aquila Technology               |          1          |
# |                   Luminar                    |          47         |
# |                  Baidu USA                   |          1          |
# |                   HYLIION                    |          2          |
# |            SAIC Innovation Center            |          7          |
# |                   Daimler                    |          67         |
# |                  OpTech US                   |          1          |
# |                DD DANNAR, LLC                |          1          |
# |                     Arup                     |          2          |
# |                   Exponent                   |          1          |
# |            Autoneum Management AG            |          1          |
# |                  Wind River                  |          1          |
# |              Ford Motor Company              |          7          |
# |          Toyota Research Institute           |          7          |
# |              Fleishman-Hillard               |          1          |
# |                   Vencore                    |          2          |
# |                   Raytheon                   |          2          |
# |                     Yext                     |          1          |
# |               Xesol Innovation               |          1          |
# |                  IBI Group                   |          1          |
# |           Abalta Technologies, Inc           |          2          |
# |             Amazon Corporate LLC             |          4          |
# |                    ZF TRW                    |          1          |
# |                Udacity, Inc.                 |          3          |
# |             State of Washington              |          1          |
# |                 Audi Canada                  |          3          |
# |                    RAC WA                    |          1          |
# |         North American Lighting, Inc         |          1          |
# |                  U.S.LADAR                   |          1          |
# |                Black-Peak Inc                |          1          |
# |                Stout Systems                 |          1          |
# |           BMW of North America LLC           |          3          |
# |     San Diego Association of Governments     |          1          |
# |               Northrop Grumman               |          9          |
# |     Affordable Engineering Services LLC      |          2          |
# |                    eXcell                    |          1          |
# |                   Drive.ai                   |          12         |
# |         Bay Systems Consulting, Inc.         |          1          |
# |                     Didi                     |          3          |
# |                 Tesla Motors                 |          11         |
# |      Qualified Technical Services, Inc       |          1          |
# |            STS Technical Services            |          2          |
# |                   Siemens                    |          2          |
# |         Toyota InfoTechnology Center         |          1          |
# |                    Kapsch                    |          2          |
# |                Applied Minds                 |          11         |
# |                Hyperloop One                 |          7          |
# |               ASG Renaissance                |          1          |
# |               Swift Navigation               |          5          |
# |               Teledyne Benthos               |          1          |
# |                   Astreya                    |          1          |
# |           Cruise Automation, Inc.            |          3          |
# |              Rutgers University              |          1          |
# |                  TEKSystems                  |          4          |
# |              Savant Automation               |          1          |
# |          Pine Gate Renewables, LLC           |          1          |
# |               Karma Automotive               |          2          |
# |                   FocusHub                   |          2          |
# |              Logic Supply, Inc.              |          1          |
# |          KAR Auction Services, Inc.          |          2          |
# |                    NAVYA                     |          1          |
# |         Solidus Technical Solutions          |          1          |
# |                 Continental                  |          5          |
# |              Applied Minds, LLC              |          5          |
# |               Perrone Robotics               |          2          |
# |         The Boston Consulting Group          |          1          |
# |              L-3 Communications              |          2          |
# |              NXP Semiconductors              |          33         |
# |                 Iteris, Inc.                 |          1          |
# |        Omron Adept Technologies, Inc.        |          1          |
# |             Omega Solutions Inc              |          1          |
# |                 Synergy ECP                  |          1          |
# |                     Flex                     |          6          |
# |     National Renewable Energy Laboratory     |          1          |
# |                    Adecco                    |          4          |
# |            Workbridge Associates             |          3          |
# |                   ektello                    |          2          |
# |                RailPod, Inc.                 |          1          |
# |     Federal Emergency Management Agency      |          1          |
# +----------------------------------------------+---------------------+

# %% [markdown]
# # WHAT skillsets?

# %%
conn = sqlite3.connect('indeed.db')
c = conn.cursor()
#select in jobs all unique values in column = employer
sql_manager = "SELECT jobkey, progskills_req FROM progskills;"
c.execute(sql_manager)
result = c.fetchall()
nb_entry = len(result)
programming = {}

for this_job in result:
    this_jobkey = this_job[0]
    prog = this_job[1]
    #make sure the extracted cell is not empty
    if len(prog) > 0:
        if prog in programming:
            programming[prog] += 1
        else:
            programming[prog] = 1


print('Total Nbr of companies {}'.format(len(programming)) )
print(programming)
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = []
sizes = []
sum_sz = 0

for this_prog in programming:
    pct = programming[this_prog]*1.0/nb_entry
    if pct > 0.05:
        sizes.append(pct)
        sum_sz = sum_sz + pct
        labels.append(this_prog)
    
others_sz = 1 - sum_sz
sizes.append(others_sz)
labels.append('others')

explode = (0.1, 0, 0, 0, 0, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')
mpl.rcParams['font.size'] = 30
fig1, ax1 = plt.subplots(figsize=(14,14))
cmap = plt.cm.Blues
colors = cmap(np.linspace(1, 0, 7))
ax1.pie(sizes, labels=labels, explode=explode, colors=colors, autopct='%1.1f%%', shadow=False, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
# Out:
# Total Nbr of companies 11
# {'ruby': 6, 'c++': 126, 'keras': 1, 'tensorflow': 13, 'matlab': 31, 'php': 2, 'ros': 23, 'java': 25, 'python': 88, 'c': 78, 'opencv': 13}

# %% [markdown]
# # Education requirement

# %%
conn = sqlite3.connect('indeed.db')
c = conn.cursor()
#select in jobs all unique values in column = employer
sql_manager = "SELECT jobkey, degrees_req FROM degrees;"
c.execute(sql_manager)
result = c.fetchall()
nb_entry = len(result)
degrees = {'Master':0, 'Bachelor': 0, 'PhD': 0}

for this_job in result:
    this_jobkey = this_job[0]
    deg = this_job[1]
    #make sure the extracted cell is not empty
    if deg in ['bachelor', 'ba', 'bs', 'bsc', 'bachelors']:
        degrees['Bachelor'] += 1
    elif deg in ['master', 'ms', 'masters', 'mba']:
        degrees['Master'] += 1
    elif deg == 'phd':
        degrees['PhD'] += 1


print('Total Nbr of degrees {}'.format(len(degrees)) )
print(degrees)
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = []
sizes = []
sum_sz = 0

for this_deg in degrees:
    pct = degrees[this_deg]*1.0/nb_entry
    if pct > 0.05:
        sizes.append(pct)
        sum_sz = sum_sz + pct
        labels.append(this_deg)

#explode = (0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')
mpl.rcParams['font.size'] = 30
fig1, ax1 = plt.subplots(figsize=(14,14))
cmap = plt.cm.Blues
colors = cmap(np.linspace(0, 1, 3))
ax1.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', shadow=False, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
# Out:
# Total Nbr of degrees 3
# {'PhD': 76, 'Master': 145, 'Bachelor': 146}

# %%
conn = sqlite3.connect('indeed.db')
c = conn.cursor()
#select in jobs all unique values in column = employer
sql_manager = "SELECT jobkey, qualifications_req FROM qualifications;"
c.execute(sql_manager)
result = c.fetchall()
nb_entry = len(result)
qualifs = {}

for this_job in result:
    this_jobkey = this_job[0]
    qualif = this_job[1]
    #make sure the extracted cell is not empty
    if qualif in ['computer science', 'cs']:
        qualif = 'Computer Sc.'
        if qualif in qualifs:
            qualifs['Computer Sc.'] += 1
        else:
            qualifs['Computer Sc.'] = 1
    
    elif qualif in ['mechanical engineering', 'me']:
        qualif = 'Mechanical Eng.'
        if qualif in qualifs:
            qualifs['Mechanical Eng.'] += 1
        else:
            qualifs['Mechanical Eng.'] = 1
            
    elif qualif == 'physics':
        if qualif in qualifs:
            qualifs['Physics'] += 1
        else:
            qualifs['Physics'] = 1
            
    elif qualif in ['industrial engineering', 'ie']:
        qualif ='Industrial Eng.'
        if qualif in qualifs:
            qualifs[qualif] += 1
        else:
            qualifs[qualif] = 1           
                    
    elif qualif in ['electrical engineering', 'ee']:
        qualif = 'Electrical Eng.'
        if qualif in qualifs:
            qualifs[qualif] += 1
        else:
            qualifs[qualif] = 1    
            
    elif qualif in ['computer engineering', 'ce']:
        qualif = 'Computer Eng.'
        if qualif in qualifs:
            qualifs[qualif] += 1
        else:
            qualifs[qualif] = 1  

print('Total Nbr of degrees {}'.format(len(qualifs)) )
print(qualifs)
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = []
sizes = []
sum_sz = 0

for this_qualif in qualifs:
    pct = qualifs[this_qualif]*1.0/nb_entry
    if pct > 0.05:
        sizes.append(pct)
        sum_sz = sum_sz + pct
        labels.append(this_qualif)

others_sz = 1 - sum_sz
sizes.append(others_sz)
labels.append('others')
#explode = (0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')
mpl.rcParams['font.size'] = 40
fig1, ax1 = plt.subplots(figsize=(14,14))
cmap = plt.cm.Blues
colors = cmap(np.linspace(1, 0, 5))
ax1.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', shadow=False, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
# Out:
# Total Nbr of degrees 6
# {'Electrical Eng.': 72, 'Computer Eng.': 8, 'Mechanical Eng.': 29, 'Computer Sc.': 135, 'Industrial Eng.': 7, 'Physics': 1}
