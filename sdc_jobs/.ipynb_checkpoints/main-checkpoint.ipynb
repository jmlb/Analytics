# %%
#Attribution: https://github.com/indeedlabs/indeed-python
from indeed import IndeedClient
import re
client = IndeedClient(publisher ="9124561496937265")
import time
import sqlite3
import glob
from bs4 import BeautifulSoup # For HTML parsing
import urllib # Website connections
import re # Regular expressions
from time import sleep # To prevent overwhelming the server between connections
from collections import Counter # Keep track of our term counts
from nltk.corpus import stopwords # Filter out stopwords, such as 'the', 'or', 'and'
import pandas as pd # For converting results to a dataframe and bar chart plots
# %matplotlib inline

# %%
class Indeed_JobScrap():
    
    def __init__(self, db_fname, overwrite_db, job_requirements_ls):
        self.overwrite_db = overwrite_db
        self.db_fname = db_fname
        self.job_requirements_ls = job_requirements_ls
        self.job_items = ["jobtitle", "date", "company", "country", "state", 
                          "longitude", "latitude"]
        self.tracker = [] #tracker how many consecutives job_response ar null
        self.thres = 3 #if 3 consecutives job detail request empty, stop 
        self.listing = {}
        self.table_name = "jobs"
        self.dbname = "job_listings"
        self.url = 'https://www.indeed.com/viewjob?jk='
        self.other_tables = ['degrees', 'progskills', 'qualifications', 'expertise']
        
    
    def connect_db(self):
        sql_files = glob.glob('*.db')
        if (self.db_fname in sql_files) or (overwrite_db == False):
            self.conn = sqlite3.connect(self.db_fname)
            self.c = self.conn.cursor()
        else:
            #open connection to local file
            self.conn = sqlite3.connect(self.db_fname)
            self.c = self.conn.cursor()
            # Create table
            try:
                self.c.execute("CREATE TABLE {} (jobkey, jobtitle, employer, date, country, state, longitude, latitude)".format(self.table_name))
                print('Created Table: {} in database {}'.format(self.table_name, self.dbname) )
                self.conn.commit()
            except:
                print('Unable to create table {}'.format(self.table_name))
            for this_table in self.other_tables:
                try:
                    col_name = this_table + '_req'
                    self.c.execute("CREATE TABLE {} (jobkey, {})".format(this_table, col_name))
                    print('Created Table: {} in database {}'.format(this_table, self.dbname) )
                    # Save (commit) the changes
                    self.conn.commit()
                except:
                        print('Unable to create table {}'.format(this_table))
                
                
                
                
    def save2db(self, job_entry):
        '''
        Save job_entry data to database: 
        jobkey, jobtitle, employer, data, country, state, longitude, latitude,
        degrees, qualifications, expertise, progskills
        '''
        #check if job in db
        sql_select = "SELECT {}.jobkey FROM {} WHERE {}.jobkey = '{}';".format(self.table_name, self.table_name, self.table_name, job_entry['jobkey'])
        flag_jobindb = False
        flag_error = False
        try:
            self.c.execute(sql_select)
            result = self.c.fetchall()
            if len(result) != 0:
                flag_jobindb = True
        except:
            # Insert a row of data
            print('Unable to execute SQL query: SELECT')
            flag_error = True
        print('job entry already recorded: {}'.format(flag_jobindb))        
        if flag_jobindb == False:
            #add job entry to jobs table
            sql_insert = "INSERT INTO {} VALUES ('{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}');".format(self.table_name, 
            job_entry['jobkey'], job_entry['jobtitle'], job_entry['company'], job_entry['date'], 
            job_entry['country'], job_entry['state'], job_entry['longitude'], job_entry['latitude'])
            try:
                self.c.execute(sql_insert)
                self.conn.commit()
                print('Job entry saved in DB')
            except:
                print('Unable to save job entry in {}'.format(self.table_name))
            
            #add entry to other_tables
            for this_table in self.other_tables:
                if len(job_entry[this_table]) != 0:
                    for item in job_entry[this_table]:
                        sql_insert = "INSERT INTO {} VALUES ('{}','{}');".format(this_table, job_entry['jobkey'], item)
                        try:
                            self.c.execute(sql_insert)
                            self.conn.commit()
                        except:
                            print('Unable to save item {} in {}'.format(item, this_table))
        else:
            #update database
            sql_update = "UPDATE {} SET {}='{}', {}='{}', {}='{}', {}='{}', {}='{}', {}='{}', {}='{}' WHERE {}.jobkey={};".format(self.table_name, 
            'job_title', job_entry['jobtitle'], 'employer', job_entry['company'], 'date', job_entry['date'], 
            'country', job_entry['country'], 'state', job_entry['state'], 'longitude', 
            job_entry['longitude'], 'latitude', job_entry['latitude'], self.table_name, job_entry['jobkey'] )
            try:
                self.c.execute(sql_update)
                self.conn.commit()
                print('Job entry saved in DB')
            except:
                print('Unable to save job entry in {}'.format(self.table_name))
            
            #add/update entry to other_tables
                            

    def sanitize_text(self, text):
        try:
            text = text.decode('unicode_escape').encode('ascii', 'ignore') 
        except:
            pass

        #Remove special characters
        special_chars = "!@#$%^&*()[]{};:,./<>?\|`~=_"
        for special_char in special_chars:
            clean_text = text.replace(special_char, " ")
        #remove newline
        clean_text = " ".join(clean_text.split())
        clean_text = re.sub("[^a-zA-Z+2]"," ", clean_text)
        return clean_text
    
    
    
    def get_jobsListing(self, keywords, start, limit):
        query = ""
        if len(keywords) > 0:
            #build query
            for item in keywords:
                query = query +"+"+item
        
            params = {
                      'q' : query,
                      # 'l' : "austin",
                      'start': start,
                      'limit': limit, #maximum nbr of results returned
                      'userip' : "1.2.3.4",
                      'useragent' : "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_2)"
                     }

            return client.search(**params)
        else:
            return []                                                                                                            


                                                                                                      
                                                                                                                        
    def snif_jobDescription(self, jobkey):
        this_url = self.url+str(jobkey)
        flag_error = False
        try:
            site = urllib.request.urlopen(this_url).read() # Connect to the job posting
            soup_obj = BeautifulSoup(site, "lxml")
        except:
            print('page not found')
            flag_error = True
        
        if flag_error == False:
            # search for all <span tag
            spans = soup_obj.find_all('span', attrs={'id':"job_summary"})
            if len(spans) == 1:
                #convert soup object to text
                text = spans[0].get_text()
                #Cleaning text
                clean_text = self.sanitize_text(text)
                text_split = clean_text.split()
                return text_split
            else:
                return ""


    def extract_jobRequirements(self, jobkey):
        #get text job description
        job_description_txt = self.snif_jobDescription(jobkey)
        #save job requirements in job_req
        job_req = {}
        #Initialize
        for i in self.job_requirements_ls:
            job_req[i] = []

        #better to scroll thru text once
        for idx, word in enumerate(job_description_txt):
            w_lower = word.lower()
            
            for key in self.job_requirements_ls:
                if key == 'expertise' or key == 'qualifications':
                    if w_lower in self.job_requirements_ls[key]:
                        if len(self.job_requirements_ls[key][w_lower])==0:
                            #the word has no child in list of job req  (like 'cs':[]) 
                            if len(job_req[key])==0:
                                job_req[key] = [w_lower]
                            elif w_lower not in job_req[key]:
                                job_req[key].append(w_lower)
                        else:
                            #check the word is not the last of the job_description (otherwise next_word does not exist)
                            if idx < len(job_description_txt)-1:
                                next_word = job_description_txt[idx+1].lower()
                                #check if expression=word+next_word is in our list of job_requirements of that key
                                if next_word in self.job_requirements_ls[key][w_lower]:
                                    expression = w_lower+" "+next_word
                                    if len(job_req[key])==0:
                                        job_req[key] = [expression]
                                    elif expression not in job_req[key]:
                                        job_req[key].append(expression)
                                
                else:
                    if w_lower in self.job_requirements_ls[key]:
                        if len(job_req[key])==0:
                            job_req[key] = [w_lower]
                        elif w_lower not in job_req[key]:
                            job_req[key].append(w_lower)
        
        return job_req

                            
    def record(self, keywords, start, limit):
        while len(self.tracker) < self.thres:
            #get more responses (pagination)
            query_response = self.get_jobsListing(keywords, start, limit)
            n_entry = 0
            print(start)
            for job_entry in query_response['results']:
                job_details = {}
                n_entry += 1
                print('********* Entry # {}'.format(n_entry))
                jobkey = job_entry['jobkey']
                job_details['jobkey'] = jobkey
                #Make a query on this jobkey
                job_entry_response = client.jobs(jobkeys = (jobkey, ))
                if len(job_entry_response['results']) > 0:
                    #reset tracker
                    self.tracker = []
                    job_entry_response = job_entry_response['results'][0]
                    ##save job specs (employer, title etc...)  ########
                    for job_item in self.job_items:
                        if job_item in job_entry_response:
                            job_details[job_item] = job_entry_response[job_item]
                        else:
                            job_details[job_item] = ""
                    
                    #extract job requirements from job description
                    job_req = self.extract_jobRequirements(jobkey)
                    job_specs = {**job_details, **job_req}
                    print(job_specs)
                    self.save2db(job_specs)       
                    time.sleep(1)
                    print('Jobkey {}'.format(jobkey))
                    print()

                else:
                    self.tracker.append(1)
            
            #check consistency n_entry and limit
            start = start + limit

# %%
degrees_ls = ['phd', 'ms', 'bsc', 'mba', 'master', 'masters', 'bachelors', 'bachelor', 'ba', 'bs']
qualifications_ls = {'cs':[], 'ce':[], 'ee':[], 'physics':[], 'electrical': ['engineering'], 'computer': ['science'],
                     'mechanical': ['engineering'], 'industrial': ['engineering']}
expertise_ls = {'machine': ['learning'], 'Deep': ['Learning'], 'computer': ['architecture'], 'Algorithms':[], 
                'GPU': ['computing'], 'parallel': ['programming'], 'Computer': ['Vision'], 
               'predictive': ['analytics'], 'vehicle':['design', 'development', 'regulations'],
               'autonomous':['vehicles'], 'robotics':[], 'radar':[], 'kinematics':[]}
progskills_ls = ['c++', 'c', 'c#', 'python', 'opencv', 'matlab', 'php', 'java', 'ruby', 'ros', 'tensorflow', 'keras']

job_requirements_ls = {'degrees': degrees_ls, 'qualifications': qualifications_ls, 'expertise': expertise_ls, 'progskills': progskills_ls}

#keywords = ['self-driving car']
#keywords = ['self-driving', 'car']
#keywords = ['autonomous', 'cars']
#keywords = ['autonomous', 'vehicles']
#keywords = ['autonomous', 'cars']
#keywords = ['autonomous-driving']
keywords = ['autonomous-driving']
start = 0
limit = 25
db_fname = 'indeed.db'
overwrite_db = True

jobsScrap = Indeed_JobScrap(db_fname, overwrite_db, job_requirements_ls)
#connect to database
jobsScrap.connect_db()

#
jobsScrap.record(keywords, start, limit)
# Out:
# 0
# ********* Entry # 1
# {'progskills': ['c', 'c++', 'python', 'tensorflow', 'matlab'], 'qualifications': [], 'country': 'US', 'latitude': 37.43956, 'date': 'Tue, 02 May 2017 02:12:16 GMT', 'expertise': ['machine learning', 'parallel programming', 'radar'], 'jobtitle': 'Autopilot Internship (Summer 2017)', 'state': 'CA', 'company': 'Tesla Motors', 'degrees': ['masters', 'bachelors'], 'jobkey': '69ca8ffcbcfa7676', 'longitude': -122.14286}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 69ca8ffcbcfa7676
#
# ********* Entry # 2
# {'progskills': [], 'qualifications': [], 'country': 'US', 'latitude': 40.453297, 'date': 'Thu, 11 May 2017 10:25:32 GMT', 'expertise': ['radar'], 'jobtitle': 'Systems Engineer - Active Safety', 'state': 'IN', 'company': 'Delphi', 'degrees': [], 'jobkey': '47934328f75dce9f', 'longitude': -86.13187}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 47934328f75dce9f
#
# ********* Entry # 3
# {'progskills': [], 'qualifications': ['computer science', 'electrical engineering'], 'country': 'US', 'latitude': 42.37088, 'date': 'Wed, 10 May 2017 03:10:35 GMT', 'expertise': [], 'jobtitle': 'Systems Engineer', 'state': 'MI', 'company': 'Bosch Group', 'degrees': ['bs', 'ms'], 'jobkey': 'a00996344d6df43b', 'longitude': -83.46703}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey a00996344d6df43b
#
# ********* Entry # 4
# {'progskills': ['c', 'c++', 'java'], 'qualifications': ['computer science', 'electrical engineering'], 'country': 'US', 'latitude': 37.354397, 'date': 'Tue, 25 Apr 2017 09:31:59 GMT', 'expertise': ['machine learning', 'radar'], 'jobtitle': 'Advanced Driver Assistance Systems - Sensor Software Engineer', 'state': 'CA', 'company': 'Intel', 'degrees': ['ms', 'bs'], 'jobkey': '2181f13fb4dcf231', 'longitude': -121.95055}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 2181f13fb4dcf231
#
# ********* Entry # 5
# {'progskills': ['c', 'c++'], 'qualifications': ['computer science', 'physics'], 'country': 'US', 'latitude': 37.43956, 'date': 'Sun, 16 Apr 2017 08:10:24 GMT', 'expertise': ['robotics', 'autonomous vehicles'], 'jobtitle': 'Autonomous Driving Systems Engineer', 'state': 'CA', 'company': 'Bosch', 'degrees': ['bachelor', 'masters'], 'jobkey': 'b7ef1b13a0611e2e', 'longitude': -122.14286}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey b7ef1b13a0611e2e
#
# ********* Entry # 6
# {'progskills': [], 'qualifications': ['computer science'], 'country': 'US', 'latitude': 33.766483, 'date': 'Thu, 13 Apr 2017 05:43:27 GMT', 'expertise': ['machine learning', 'vehicle design'], 'jobtitle': 'Development Engineer, Connectivity Systems', 'state': 'CA', 'company': 'Daimler', 'degrees': ['bachelor'], 'jobkey': '5820b91b7a9c5a44', 'longitude': -118.18681}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 5820b91b7a9c5a44
#
# ********* Entry # 7
# {'progskills': ['matlab'], 'qualifications': [], 'country': 'US', 'latitude': 42.37088, 'date': 'Thu, 13 Apr 2017 03:10:53 GMT', 'expertise': [], 'jobtitle': 'Global Navigation Satellite Systems Engineer', 'state': 'MI', 'company': 'Bosch Group', 'degrees': ['bs', 'ms', 'phd'], 'jobkey': 'ffa2f74f64cc5caf', 'longitude': -83.46703}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey ffa2f74f64cc5caf
#
# ********* Entry # 8
# {'progskills': ['c++', 'python', 'ros', 'c'], 'qualifications': ['cs'], 'country': 'US', 'latitude': 37.43956, 'date': 'Sun, 16 Apr 2017 08:09:49 GMT', 'expertise': ['autonomous vehicles'], 'jobtitle': 'Autonomous Driving Software Developer', 'state': 'CA', 'company': 'Bosch', 'degrees': ['bs', 'ms', 'phd'], 'jobkey': '2f000f5fb372b471', 'longitude': -122.14286}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 2f000f5fb372b471
#
# ********* Entry # 9
# {'progskills': ['tensorflow', 'opencv', 'ros'], 'qualifications': ['electrical engineering', 'computer science', 'physics'], 'country': 'US', 'latitude': 37.35165, 'date': 'Sat, 06 May 2017 03:31:21 GMT', 'expertise': ['robotics', 'radar', 'kinematics'], 'jobtitle': 'Signal Processing Engineer for Robotics', 'state': 'CA', 'company': 'Intellipro Group Inc.', 'degrees': ['ms', 'phd'], 'jobkey': 'af771977b0069782', 'longitude': -121.95055}
# job entry already recorded: False
# Job entry saved in DB
# Jobkey af771977b0069782
#
# ********* Entry # 10
# {'progskills': [], 'qualifications': ['computer science', 'mechanical engineering'], 'country': 'US', 'latitude': 37.368134, 'date': 'Fri, 31 Mar 2017 05:54:23 GMT', 'expertise': ['machine learning', 'vehicle design'], 'jobtitle': 'Systems Engineer', 'state': 'CA', 'company': 'Daimler', 'degrees': ['bachelors'], 'jobkey': '5df83d90dc101b11', 'longitude': -122.03297}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 5df83d90dc101b11
#
# ********* Entry # 11
# {'progskills': ['c', 'c++'], 'qualifications': ['computer science', 'mechanical engineering', 'electrical engineering'], 'country': 'US', 'latitude': 42.373627, 'date': 'Tue, 28 Mar 2017 18:17:12 GMT', 'expertise': ['robotics', 'radar'], 'jobtitle': 'Robotics Hardware Engineer - Autonomous Driving', 'state': 'MA', 'company': 'MIT', 'degrees': ['bachelor'], 'jobkey': '9f85e0104c48a7c4', 'longitude': -71.10439}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 9f85e0104c48a7c4
#
# ********* Entry # 12
# {'progskills': [], 'qualifications': ['computer science', 'electrical engineering'], 'country': 'US', 'latitude': 37.384617, 'date': 'Fri, 10 Mar 2017 10:45:14 GMT', 'expertise': ['machine learning'], 'jobtitle': 'Software Developer, Autonomous Vehicle Localization', 'state': 'CA', 'company': 'BMW of North America LLC', 'degrees': ['masters'], 'jobkey': 'ff5f08a914033b87', 'longitude': -122.08242}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey ff5f08a914033b87
#
# ********* Entry # 13
# {'progskills': ['c'], 'qualifications': ['computer science', 'physics'], 'country': 'US', 'latitude': 34.42033, 'date': 'Sun, 09 Apr 2017 08:55:08 GMT', 'expertise': ['machine learning'], 'jobtitle': 'Algorithm Development Engineer for Advanced Drivers Assistance Systems', 'state': 'CA', 'company': 'Continental', 'degrees': ['master'], 'jobkey': 'f06dc6b7910b8735', 'longitude': -119.6978}
# job entry already recorded: False
# Job entry saved in DB
# Jobkey f06dc6b7910b8735
#
# ********* Entry # 14
# {'progskills': ['c++'], 'qualifications': ['electrical engineering', 'computer science'], 'country': 'US', 'latitude': 37.368134, 'date': 'Sun, 16 Apr 2017 23:57:53 GMT', 'expertise': ['machine learning', 'vehicle design', 'autonomous vehicles', 'radar'], 'jobtitle': 'Autonomous Driving Intern, Sensor Fusion and Localization', 'state': 'CA', 'company': 'Daimler', 'degrees': ['bachelor', 'master', 'phd'], 'jobkey': '79cc40f18e2921da', 'longitude': -122.03297}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 79cc40f18e2921da
#
# ********* Entry # 15
# {'progskills': ['c', 'c++'], 'qualifications': ['computer science', 'physics'], 'country': 'US', 'latitude': 37.43956, 'date': 'Tue, 21 Feb 2017 04:08:30 GMT', 'expertise': ['robotics'], 'jobtitle': 'Autonomous Driving Systems Engineer', 'state': 'CA', 'company': 'Bosch Group', 'degrees': ['bachelor', 'masters', 'master'], 'jobkey': '59cbf8adc6672466', 'longitude': -122.14286}
# job entry already recorded: False
# Job entry saved in DB
# Jobkey 59cbf8adc6672466
#
# ********* Entry # 16
# {'progskills': ['matlab', 'python', 'c++'], 'qualifications': ['computer science', 'mechanical engineering'], 'country': 'US', 'latitude': 37.368134, 'date': 'Mon, 08 May 2017 23:21:43 GMT', 'expertise': ['machine learning', 'vehicle design'], 'jobtitle': 'Machine Learning Engineer', 'state': 'CA', 'company': 'Daimler', 'degrees': ['bachelors'], 'jobkey': 'b9f5f88f40fc19c7', 'longitude': -122.03297}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey b9f5f88f40fc19c7
#
# ********* Entry # 17
# ********* Entry # 18
# ********* Entry # 19
# {'progskills': ['c++', 'python', 'ros'], 'qualifications': ['computer science'], 'country': 'US', 'latitude': 37.337914, 'date': 'Sat, 11 Mar 2017 08:58:04 GMT', 'expertise': [], 'jobtitle': 'Software Engineer - Visualization for Robotics/Automated Driving', 'state': 'CA', 'company': 'Faraday Future, Inc.', 'degrees': [], 'jobkey': '9ebe28d7c8df1bd8', 'longitude': -121.89011}
# job entry already recorded: False
# Job entry saved in DB
# Jobkey 9ebe28d7c8df1bd8
#
# ********* Entry # 20
# ********* Entry # 21
# {'progskills': ['c++', 'matlab', 'python', 'c'], 'qualifications': ['computer science'], 'country': 'US', 'latitude': 37.43956, 'date': 'Sun, 16 Apr 2017 08:09:44 GMT', 'expertise': ['machine learning', 'robotics', 'autonomous vehicles'], 'jobtitle': 'Autonomous Driving Machine Learning Engineer', 'state': 'CA', 'company': 'Bosch', 'degrees': ['master'], 'jobkey': '03863308b43a5d97', 'longitude': -122.14286}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 03863308b43a5d97
#
# ********* Entry # 22
# {'progskills': ['python', 'c++'], 'qualifications': ['computer science'], 'country': 'US', 'latitude': 37.51923, 'date': 'Fri, 14 Apr 2017 03:11:30 GMT', 'expertise': ['machine learning'], 'jobtitle': 'Mid-level Deep Learning Engineer, Autonomous Driving', 'state': 'CA', 'company': 'Raag Solutions .LLC', 'degrees': [], 'jobkey': 'ced97bb63f459faf', 'longitude': -122.27473}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey ced97bb63f459faf
#
# ********* Entry # 23
# {'progskills': ['python', 'c++', 'tensorflow', 'keras'], 'qualifications': ['computer science'], 'country': 'US', 'latitude': 37.384617, 'date': 'Tue, 11 Apr 2017 20:05:45 GMT', 'expertise': ['machine learning', 'robotics'], 'jobtitle': 'Machine Learning Engineer', 'state': 'CA', 'company': 'Toyota Research Institute', 'degrees': ['ms', 'bs'], 'jobkey': 'df4a406861a4c927', 'longitude': -122.10989}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey df4a406861a4c927
#
# ********* Entry # 24
# {'progskills': ['java'], 'qualifications': ['computer science'], 'country': 'US', 'latitude': 47.604397, 'date': 'Fri, 24 Mar 2017 19:15:19 GMT', 'expertise': [], 'jobtitle': 'Lead Engineer - Big Data', 'state': 'WA', 'company': 'HERE', 'degrees': [], 'jobkey': '48a3f67f48f8b8cb', 'longitude': -122.32967}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 48a3f67f48f8b8cb
#
# ********* Entry # 25
# 25
# ********* Entry # 1
# {'progskills': ['python', 'c', 'c++'], 'qualifications': ['computer science'], 'country': 'US', 'latitude': 37.87088, 'date': 'Sat, 06 May 2017 06:57:16 GMT', 'expertise': ['machine learning'], 'jobtitle': 'Lead Research Engineer, Visual-Lidar Odometry', 'state': 'CA', 'company': 'HERE', 'degrees': ['master', 'phd'], 'jobkey': 'd86329fbb6e49136', 'longitude': -122.26923}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey d86329fbb6e49136
#
# ********* Entry # 2
# {'progskills': ['c++', 'python', 'tensorflow'], 'qualifications': ['computer science'], 'country': 'US', 'latitude': 37.87088, 'date': 'Sat, 06 May 2017 06:55:53 GMT', 'expertise': ['machine learning'], 'jobtitle': 'Lead Software Engineer (Autonomous Driving)', 'state': 'CA', 'company': 'HERE', 'degrees': ['bachelors', 'masters'], 'jobkey': 'ab7b3a7e426b5837', 'longitude': -122.26923}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey ab7b3a7e426b5837
#
# ********* Entry # 3
# {'progskills': ['tensorflow', 'python'], 'qualifications': ['computer science'], 'country': 'US', 'latitude': 32.714287, 'date': 'Fri, 17 Mar 2017 20:28:26 GMT', 'expertise': ['machine learning'], 'jobtitle': 'Staff Machine Learning/Computer Vision Engineer (Platform)', 'state': 'CA', 'company': 'smartdrive', 'degrees': ['bs'], 'jobkey': '2e8e2366e5b97e60', 'longitude': -117.15385}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 2e8e2366e5b97e60
#
# ********* Entry # 4
# {'progskills': ['c++', 'java', 'ros'], 'qualifications': ['computer science', 'electrical engineering'], 'country': 'US', 'latitude': 37.337914, 'date': 'Fri, 05 May 2017 05:42:28 GMT', 'expertise': ['robotics'], 'jobtitle': 'Linux System Engineer', 'state': 'CA', 'company': 'SAIC Innovation Center', 'degrees': ['ms', 'phd'], 'jobkey': '92e57e8603d3a045', 'longitude': -121.89011}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 92e57e8603d3a045
#
# ********* Entry # 5
# {'progskills': [], 'qualifications': [], 'country': 'US', 'latitude': 42.32967, 'date': 'Fri, 12 May 2017 14:00:44 GMT', 'expertise': [], 'jobtitle': '3D Designer', 'state': 'MI', 'company': 'TEORESI INC.', 'degrees': ['bachelor'], 'jobkey': '71e2178fbf799136', 'longitude': -83.04395}
# job entry already recorded: False
# Job entry saved in DB
# Jobkey 71e2178fbf799136
#
# ********* Entry # 6
# {'progskills': [], 'qualifications': [], 'country': 'US', 'latitude': 37.368134, 'date': 'Thu, 11 May 2017 23:26:46 GMT', 'expertise': ['machine learning', 'vehicle design'], 'jobtitle': 'Senior Software Engineer - Architect', 'state': 'CA', 'company': 'Daimler', 'degrees': ['bachelors', 'masters', 'phd'], 'jobkey': 'c6d7a41f27ee0e4b', 'longitude': -122.03297}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey c6d7a41f27ee0e4b
#
# ********* Entry # 7
# {'progskills': [], 'qualifications': [], 'country': 'US', 'latitude': 32.714287, 'date': 'Sat, 13 May 2017 02:30:38 GMT', 'expertise': [], 'jobtitle': 'Recruiter Specialist', 'state': 'CA', 'company': 'TuSimple', 'degrees': ['ms'], 'jobkey': 'abaef4502d01b183', 'longitude': -117.15385}
# job entry already recorded: False
# Job entry saved in DB
# Jobkey abaef4502d01b183
#
# ********* Entry # 8
# {'progskills': ['java'], 'qualifications': ['computer science'], 'country': 'US', 'latitude': 41.8489, 'date': 'Tue, 11 Apr 2017 19:20:19 GMT', 'expertise': ['machine learning'], 'jobtitle': 'Lead Front End Engineer', 'state': 'IL', 'company': 'HERE', 'degrees': ['bs'], 'jobkey': 'e81e71f34b2de050', 'longitude': -87.64835}
# job entry already recorded: False
# Job entry saved in DB
# Jobkey e81e71f34b2de050
#
# ********* Entry # 9
# {'progskills': [], 'qualifications': ['computer science'], 'country': 'US', 'latitude': 37.4093, 'date': 'Tue, 02 May 2017 00:02:55 GMT', 'expertise': [], 'jobtitle': 'Fullstack Software Engineer', 'state': 'CA', 'company': 'Baidu USA', 'degrees': ['bachelor'], 'jobkey': 'ce559419641752a8', 'longitude': -122.02388}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey ce559419641752a8
#
# ********* Entry # 10
# {'progskills': [], 'qualifications': ['computer science'], 'country': 'US', 'latitude': 47.604397, 'date': 'Wed, 22 Mar 2017 01:03:04 GMT', 'expertise': ['machine learning'], 'jobtitle': 'Lead Engineer', 'state': 'WA', 'company': 'HERE', 'degrees': [], 'jobkey': '2ac20d53c97d2ab8', 'longitude': -122.32967}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 2ac20d53c97d2ab8
#
# ********* Entry # 11
# {'progskills': ['java'], 'qualifications': ['computer science'], 'country': 'US', 'latitude': 47.604397, 'date': 'Tue, 21 Mar 2017 19:06:33 GMT', 'expertise': ['machine learning'], 'jobtitle': 'Lead Java Engineer', 'state': 'WA', 'company': 'HERE', 'degrees': [], 'jobkey': 'e1d73c7ce5ea6e0c', 'longitude': -122.32967}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey e1d73c7ce5ea6e0c
#
# ********* Entry # 12
# {'progskills': ['c', 'c++', 'java'], 'qualifications': ['computer science'], 'country': 'US', 'latitude': 47.652508, 'date': 'Tue, 09 May 2017 05:27:32 GMT', 'expertise': [], 'jobtitle': 'SOFTWARE ENGINEER', 'state': 'WA', 'company': 'Microsoft', 'degrees': ['bs', 'ms'], 'jobkey': '7fa52a6f6d764f41', 'longitude': -122.14208}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 7fa52a6f6d764f41
#
# ********* Entry # 13
# {'progskills': [], 'qualifications': ['mechanical engineering'], 'country': 'US', 'latitude': 33.766483, 'date': 'Wed, 03 May 2017 23:08:24 GMT', 'expertise': ['machine learning', 'vehicle design'], 'jobtitle': 'Engineering Intern - Overall Vehicle Testing & Durability', 'state': 'CA', 'company': 'Daimler', 'degrees': ['ms'], 'jobkey': 'b2deb31ce057fe5a', 'longitude': -118.18681}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey b2deb31ce057fe5a
#
# ********* Entry # 14
# {'progskills': [], 'qualifications': ['ee', 'cs'], 'country': 'US', 'latitude': 37.29121, 'date': 'Thu, 04 May 2017 10:21:06 GMT', 'expertise': [], 'jobtitle': 'Automotive Functional Safety Specialist', 'state': 'CA', 'company': 'Intel', 'degrees': [], 'jobkey': 'bbdcab3dfee1115c', 'longitude': -121.89561}
# job entry already recorded: False
# Job entry saved in DB
# Jobkey bbdcab3dfee1115c
#
# ********* Entry # 15
# {'progskills': [], 'qualifications': [], 'country': 'US', 'latitude': 34.01923, 'date': 'Wed, 19 Apr 2017 14:39:04 GMT', 'expertise': [], 'jobtitle': 'Entry Level Graphic Designer', 'state': 'CA', 'company': 'Tesloop', 'degrees': [], 'jobkey': '272b99aa59e1d35e', 'longitude': -118.39561}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 272b99aa59e1d35e
#
# ********* Entry # 16
# {'progskills': ['c', 'c++', 'python'], 'qualifications': ['computer science'], 'country': 'US', 'latitude': 32.714287, 'date': 'Sat, 29 Apr 2017 01:41:11 GMT', 'expertise': ['robotics'], 'jobtitle': 'Autonomous Driving Software Engineer Full-Time/Internship', 'state': 'CA', 'company': 'TuSimple', 'degrees': ['ms'], 'jobkey': 'acee9380b71581e4', 'longitude': -117.15385}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey acee9380b71581e4
#
# ********* Entry # 17
# {'progskills': ['c++', 'python'], 'qualifications': ['physics', 'computer science'], 'country': 'US', 'latitude': 37.384617, 'date': 'Mon, 08 May 2017 05:55:41 GMT', 'expertise': ['autonomous vehicles', 'robotics'], 'jobtitle': 'Simulation Engineer', 'state': 'CA', 'company': 'Drive.ai', 'degrees': ['ms', 'phd'], 'jobkey': '8ffdbe0434829389', 'longitude': -122.08242}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 8ffdbe0434829389
#
# ********* Entry # 18
# {'progskills': ['c++', 'java', 'python', 'ros'], 'qualifications': ['computer science', 'electrical engineering'], 'country': 'US', 'latitude': 37.337914, 'date': 'Fri, 05 May 2017 05:42:39 GMT', 'expertise': ['robotics', 'machine learning'], 'jobtitle': 'Research Engineer (Path Planning)', 'state': 'CA', 'company': 'SAIC Innovation Center', 'degrees': ['ms', 'phd'], 'jobkey': 'fbed5891a2bb6012', 'longitude': -121.89011}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey fbed5891a2bb6012
#
# ********* Entry # 19
# {'progskills': ['c++', 'java', 'python', 'tensorflow'], 'qualifications': ['computer science', 'electrical engineering'], 'country': 'US', 'latitude': 37.337914, 'date': 'Fri, 05 May 2017 05:42:39 GMT', 'expertise': ['robotics'], 'jobtitle': 'Research Engineer (Deep Learning)', 'state': 'CA', 'company': 'SAIC Innovation Center', 'degrees': ['ms', 'phd'], 'jobkey': 'f33ff626f7d9197b', 'longitude': -121.89011}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey f33ff626f7d9197b
#
# ********* Entry # 20
# {'progskills': ['c++', 'java', 'python', 'ros'], 'qualifications': ['computer science', 'electrical engineering'], 'country': 'US', 'latitude': 37.337914, 'date': 'Fri, 05 May 2017 05:42:34 GMT', 'expertise': ['robotics', 'machine learning'], 'jobtitle': 'Research Engineer (Lidar)', 'state': 'CA', 'company': 'SAIC Innovation Center', 'degrees': ['ms', 'phd'], 'jobkey': '843bbb03d933a281', 'longitude': -121.89011}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 843bbb03d933a281
#
# ********* Entry # 21
# {'progskills': ['c++', 'java', 'python', 'ros'], 'qualifications': ['computer science', 'electrical engineering'], 'country': 'US', 'latitude': 37.337914, 'date': 'Fri, 05 May 2017 05:42:29 GMT', 'expertise': ['robotics', 'machine learning'], 'jobtitle': 'Research Engineer (Mapping and Localization)', 'state': 'CA', 'company': 'SAIC Innovation Center', 'degrees': ['ms', 'phd'], 'jobkey': '36198b87ed83851b', 'longitude': -121.89011}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 36198b87ed83851b
#
# ********* Entry # 22
# {'progskills': ['c++', 'java', 'python', 'ros'], 'qualifications': ['computer science', 'electrical engineering'], 'country': 'US', 'latitude': 37.337914, 'date': 'Fri, 05 May 2017 05:42:27 GMT', 'expertise': ['robotics', 'machine learning'], 'jobtitle': 'Research Engineer (Reinforcement Learning)', 'state': 'CA', 'company': 'SAIC Innovation Center', 'degrees': ['ms', 'phd'], 'jobkey': 'f93ebbd499e5c748', 'longitude': -121.89011}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey f93ebbd499e5c748
#
# ********* Entry # 23
# {'progskills': [], 'qualifications': [], 'country': 'US', 'latitude': 32.714287, 'date': 'Thu, 04 May 2017 08:00:30 GMT', 'expertise': [], 'jobtitle': 'Public Relations Specialist (Full-Time)', 'state': 'CA', 'company': 'TuSimple', 'degrees': ['bachelor'], 'jobkey': '8fa5b56cdf0dee45', 'longitude': -117.15385}
# job entry already recorded: False
# Job entry saved in DB
# Jobkey 8fa5b56cdf0dee45
#
# ********* Entry # 24
# {'progskills': ['c', 'c++', 'python', 'ros'], 'qualifications': ['computer science'], 'country': 'US', 'latitude': 37.453297, 'date': 'Thu, 11 May 2017 02:21:17 GMT', 'expertise': ['autonomous vehicles', 'robotics'], 'jobtitle': 'Autonomous Driving / ADAS Internship', 'state': 'CA', 'company': 'Lucid Motors', 'degrees': ['master'], 'jobkey': '75b6a3b2e9d41640', 'longitude': -122.18132}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 75b6a3b2e9d41640
#
# ********* Entry # 25
# {'progskills': [], 'qualifications': [], 'country': 'US', 'latitude': 42.277473, 'date': 'Mon, 08 May 2017 23:21:37 GMT', 'expertise': ['machine learning', 'vehicle design'], 'jobtitle': 'US Press Coordinator', 'state': 'MI', 'company': 'Daimler', 'degrees': ['bachelor'], 'jobkey': '491b6fb499b94b69', 'longitude': -83.73627}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 491b6fb499b94b69
#
# 50
# ********* Entry # 1
# {'progskills': ['c', 'c++', 'opencv', 'matlab', 'python'], 'qualifications': ['computer science'], 'country': 'US', 'latitude': 42.21978, 'date': 'Tue, 09 May 2017 15:56:08 GMT', 'expertise': ['autonomous vehicles', 'radar', 'machine learning'], 'jobtitle': 'Autonomous Driving System Integration Expert', 'state': 'MI', 'company': 'Visteon Corporation', 'degrees': ['phd'], 'jobkey': 'd00ba1c5b8234aa4', 'longitude': -83.48351}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey d00ba1c5b8234aa4
#
# ********* Entry # 2
# {'progskills': [], 'qualifications': [], 'country': 'US', 'latitude': 33.156593, 'date': 'Fri, 05 May 2017 05:09:56 GMT', 'expertise': ['machine learning', 'vehicle design'], 'jobtitle': 'Exterior Design Internship', 'state': 'CA', 'company': 'Daimler', 'degrees': [], 'jobkey': '5cbbafce02ee2659', 'longitude': -117.34615}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 5cbbafce02ee2659
#
# ********* Entry # 3
# ********* Entry # 4
# {'progskills': ['c++'], 'qualifications': ['computer science'], 'country': 'US', 'latitude': 37.43956, 'date': 'Fri, 12 May 2017 03:11:05 GMT', 'expertise': ['robotics', 'machine learning'], 'jobtitle': 'Autonomous Driving - Planning / Robotics Research Engineer', 'state': 'CA', 'company': 'Bosch Group', 'degrees': [], 'jobkey': 'b04ede426bceefde', 'longitude': -122.14286}
# job entry already recorded: False
# Job entry saved in DB
# Jobkey b04ede426bceefde
#
# ********* Entry # 5
# {'progskills': [], 'qualifications': [], 'country': 'US', 'latitude': 39.73901, 'date': 'Fri, 24 Mar 2017 19:15:50 GMT', 'expertise': ['machine learning'], 'jobtitle': 'Lead Research Engineer - Highly Automated Driving', 'state': 'CO', 'company': 'HERE', 'degrees': [], 'jobkey': '440aca03cce7141c', 'longitude': -104.98351}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 440aca03cce7141c
#
# ********* Entry # 6
# {'progskills': ['python', 'c++', 'ros'], 'qualifications': ['computer science'], 'country': 'US', 'latitude': 37.4093, 'date': 'Wed, 12 Apr 2017 05:55:44 GMT', 'expertise': [], 'jobtitle': 'Integration and Release Engineer', 'state': 'CA', 'company': 'Baidu USA', 'degrees': ['ba', 'bs'], 'jobkey': 'ae50dd9e49a69896', 'longitude': -122.02388}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey ae50dd9e49a69896
#
# ********* Entry # 7
# {'progskills': ['c', 'c++'], 'qualifications': ['computer science'], 'country': 'US', 'latitude': 37.29121, 'date': 'Sun, 07 May 2017 10:23:26 GMT', 'expertise': ['autonomous vehicles'], 'jobtitle': 'FPGA Design Engineer', 'state': 'CA', 'company': 'Intel', 'degrees': [], 'jobkey': '6693294bdebeeb62', 'longitude': -121.89561}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 6693294bdebeeb62
#
# ********* Entry # 8
# {'progskills': ['c', 'c++', 'matlab'], 'qualifications': ['computer science'], 'country': 'US', 'latitude': 37.29121, 'date': 'Sun, 07 May 2017 10:23:26 GMT', 'expertise': ['autonomous vehicles'], 'jobtitle': 'Algorithms Design Engineer', 'state': 'CA', 'company': 'Intel', 'degrees': [], 'jobkey': 'e138fd237cd3799b', 'longitude': -121.89561}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey e138fd237cd3799b
#
# ********* Entry # 9
# {'progskills': [], 'qualifications': [], 'country': 'US', 'latitude': 37.43956, 'date': 'Fri, 05 May 2017 10:17:36 GMT', 'expertise': [], 'jobtitle': 'Research Engineer - Automotive Cyber Security', 'state': 'CA', 'company': 'Ford Motor Company', 'degrees': ['bachelor'], 'jobkey': '17d9269273c03e17', 'longitude': -122.14286}
# job entry already recorded: False
# Job entry saved in DB
# Jobkey 17d9269273c03e17
#
# ********* Entry # 10
# {'progskills': ['c'], 'qualifications': ['computer science'], 'country': 'US', 'latitude': 47.76099, 'date': 'Tue, 09 May 2017 12:24:47 GMT', 'expertise': [], 'jobtitle': 'Software Engineer - Automotive Cloud', 'state': 'WA', 'company': 'Elektrobit Automotive', 'degrees': ['bachelor', 'ms'], 'jobkey': '0ca95d538d30b282', 'longitude': -122.2033}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 0ca95d538d30b282
#
# ********* Entry # 11
# {'progskills': ['c++'], 'qualifications': [], 'country': 'US', 'latitude': 37.368134, 'date': 'Fri, 14 Apr 2017 05:46:09 GMT', 'expertise': ['machine learning', 'vehicle design'], 'jobtitle': 'Senior UX Software Engineer', 'state': 'CA', 'company': 'Daimler', 'degrees': [], 'jobkey': 'ded0482b320a2eff', 'longitude': -122.03297}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey ded0482b320a2eff
#
# ********* Entry # 12
# {'progskills': [], 'qualifications': [], 'country': 'US', 'latitude': 33.92008, 'date': 'Wed, 22 Mar 2017 10:31:05 GMT', 'expertise': [], 'jobtitle': 'Corporate Spokesperson', 'state': 'GA', 'company': 'Porsche Cars North America', 'degrees': ['bachelor', 'master'], 'jobkey': '2f8d8a3304c84326', 'longitude': -84.356445}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 2f8d8a3304c84326
#
# ********* Entry # 13
# {'progskills': [], 'qualifications': ['electrical engineering'], 'country': 'US', 'latitude': 37.29121, 'date': 'Wed, 03 May 2017 10:29:28 GMT', 'expertise': ['autonomous vehicles'], 'jobtitle': 'Automotive Power Business Development Engineer', 'state': 'CA', 'company': 'Intel', 'degrees': ['bs', 'mba'], 'jobkey': '08cb75cfd14213c8', 'longitude': -121.89561}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 08cb75cfd14213c8
#
# ********* Entry # 14
# ********* Entry # 15
# ********* Entry # 16
# {'progskills': ['c++'], 'qualifications': [], 'country': 'US', 'latitude': 37.384617, 'date': 'Tue, 11 Apr 2017 20:05:45 GMT', 'expertise': ['machine learning', 'robotics'], 'jobtitle': 'Senior Software Engineer, Autonomous Driving', 'state': 'CA', 'company': 'Toyota Research Institute', 'degrees': [], 'jobkey': 'c980f7a7d6b3286a', 'longitude': -122.10989}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey c980f7a7d6b3286a
#
# ********* Entry # 17
# {'progskills': ['c++', 'java', 'python', 'ros', 'matlab'], 'qualifications': ['computer science', 'electrical engineering'], 'country': 'US', 'latitude': 37.337914, 'date': 'Fri, 05 May 2017 05:42:38 GMT', 'expertise': ['robotics'], 'jobtitle': 'Software Engineer', 'state': 'CA', 'company': 'SAIC Innovation Center', 'degrees': ['ms', 'phd'], 'jobkey': '2023aefe4e506eb7', 'longitude': -121.89011}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 2023aefe4e506eb7
#
# ********* Entry # 18
# {'progskills': ['c++', 'python', 'matlab'], 'qualifications': ['computer science', 'electrical engineering'], 'country': 'US', 'latitude': 37.87088, 'date': 'Tue, 14 Mar 2017 01:52:21 GMT', 'expertise': ['machine learning'], 'jobtitle': 'Lead Research Engineer, Autonomous Driving', 'state': 'CA', 'company': 'HERE', 'degrees': ['phd', 'masters'], 'jobkey': '90a2810e4ea2d3b0', 'longitude': -122.26923}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 90a2810e4ea2d3b0
#
# ********* Entry # 19
# {'progskills': ['c', 'c++'], 'qualifications': [], 'country': 'US', 'latitude': 37.519276, 'date': 'Mon, 10 Apr 2017 05:39:33 GMT', 'expertise': [], 'jobtitle': 'Senior Software Engineer - Graphics', 'state': 'CA', 'company': 'Volkswagen Group of America, Inc.', 'degrees': ['bachelors', 'masters'], 'jobkey': 'c71120f605a5b4ed', 'longitude': -122.2762}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey c71120f605a5b4ed
#
# ********* Entry # 20
# {'progskills': ['c++'], 'qualifications': ['computer science', 'mechanical engineering'], 'country': 'US', 'latitude': 37.384617, 'date': 'Fri, 14 Apr 2017 05:54:42 GMT', 'expertise': ['autonomous vehicles', 'robotics'], 'jobtitle': 'Controls Engineer', 'state': 'CA', 'company': 'Drive.ai', 'degrees': ['phd'], 'jobkey': '0e628b36a90aebc9', 'longitude': -122.08242}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 0e628b36a90aebc9
#
# ********* Entry # 21
# {'progskills': ['python', 'java', 'c', 'c++'], 'qualifications': ['computer science'], 'country': 'US', 'latitude': 41.8489, 'date': 'Sun, 12 Mar 2017 08:00:18 GMT', 'expertise': [], 'jobtitle': 'Lead Software Engineer - Python', 'state': 'IL', 'company': 'HERE', 'degrees': [], 'jobkey': '4ebde13463d8d604', 'longitude': -87.64835}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 4ebde13463d8d604
#
# ********* Entry # 22
# {'progskills': [], 'qualifications': ['electrical engineering', 'mechanical engineering'], 'country': 'US', 'latitude': 37.368134, 'date': 'Wed, 08 Mar 2017 18:05:15 GMT', 'expertise': ['machine learning', 'vehicle design'], 'jobtitle': 'Prototype Engineering Lead', 'state': 'CA', 'company': 'Daimler', 'degrees': [], 'jobkey': '79831e848b0064e7', 'longitude': -122.03297}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 79831e848b0064e7
#
# ********* Entry # 23
# {'progskills': ['c', 'c++'], 'qualifications': ['computer science', 'electrical engineering'], 'country': 'US', 'latitude': 45.531906, 'date': 'Sun, 19 Mar 2017 10:16:48 GMT', 'expertise': [], 'jobtitle': 'Software Engineer 2017', 'state': 'OR', 'company': 'Intel', 'degrees': ['bachelor', 'master', 'phd'], 'jobkey': 'fd33a6287520b4fa', 'longitude': -122.92758}
# job entry already recorded: False
# Job entry saved in DB
# Jobkey fd33a6287520b4fa
#
# ********* Entry # 24
# {'progskills': [], 'qualifications': ['computer science'], 'country': 'US', 'latitude': 37.368134, 'date': 'Thu, 13 Apr 2017 05:43:29 GMT', 'expertise': ['machine learning', 'vehicle design'], 'jobtitle': 'Interaction Designer', 'state': 'CA', 'company': 'Daimler', 'degrees': ['bachelor'], 'jobkey': 'fafcd0c90e9d30ac', 'longitude': -122.03297}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey fafcd0c90e9d30ac
#
# ********* Entry # 25
# {'progskills': ['java', 'c++', 'python', 'c'], 'qualifications': ['computer science'], 'country': 'US', 'latitude': 34.052197, 'date': 'Thu, 27 Apr 2017 21:04:40 GMT', 'expertise': ['robotics'], 'jobtitle': 'VP of Autonomous Software', 'state': 'CA', 'company': 'Hyperloop One', 'degrees': ['bachelor', 'phd', 'masters'], 'jobkey': '2f96bf78b031c1c1', 'longitude': -118.24176}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 2f96bf78b031c1c1
#
# 75
# ********* Entry # 1
# {'progskills': ['c++'], 'qualifications': ['electrical engineering', 'computer science', 'physics'], 'country': 'US', 'latitude': 37.384617, 'date': 'Tue, 11 Apr 2017 20:05:32 GMT', 'expertise': ['radar', 'robotics', 'autonomous vehicles'], 'jobtitle': 'Advanced Sensor Simulation', 'state': 'CA', 'company': 'Toyota Research Institute', 'degrees': ['ms'], 'jobkey': 'cdaf95a77e394dee', 'longitude': -122.10989}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey cdaf95a77e394dee
#
# ********* Entry # 2
# {'progskills': [], 'qualifications': ['computer science'], 'country': 'US', 'latitude': 41.8489, 'date': 'Tue, 09 May 2017 01:04:15 GMT', 'expertise': [], 'jobtitle': 'Corporate Strategy Analyst', 'state': 'IL', 'company': 'HERE', 'degrees': [], 'jobkey': '382ebf2a59967173', 'longitude': -87.64835}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 382ebf2a59967173
#
# ********* Entry # 3
# {'progskills': [], 'qualifications': [], 'country': 'US', 'latitude': 37.37912, 'date': 'Sat, 13 May 2017 10:30:25 GMT', 'expertise': [], 'jobtitle': 'Simulation Engineer - Scripting', 'state': 'CA', 'company': 'Delphi', 'degrees': ['bachelor', 'master', 'phd'], 'jobkey': '411a7f1fc9347288', 'longitude': -122.07692}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 411a7f1fc9347288
#
# ********* Entry # 4
# {'progskills': [], 'qualifications': ['physics'], 'country': 'US', 'latitude': 37.37912, 'date': 'Sat, 13 May 2017 10:30:18 GMT', 'expertise': [], 'jobtitle': 'Simulation Engineer - Simulation Engine Development', 'state': 'CA', 'company': 'Delphi', 'degrees': ['bachelor', 'master', 'phd'], 'jobkey': '2f9afc66f78bcab0', 'longitude': -122.07692}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 2f9afc66f78bcab0
#
# ********* Entry # 5
# {'progskills': [], 'qualifications': ['physics'], 'country': 'US', 'latitude': 37.37912, 'date': 'Sat, 13 May 2017 10:30:18 GMT', 'expertise': [], 'jobtitle': 'Simulation Engineer - Object Dynamics', 'state': 'CA', 'company': 'Delphi', 'degrees': ['bachelor', 'master', 'phd'], 'jobkey': '9763ea0ddf4d04ef', 'longitude': -122.07692}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 9763ea0ddf4d04ef
#
# ********* Entry # 6
# {'progskills': [], 'qualifications': ['computer science'], 'country': 'US', 'latitude': 37.368134, 'date': 'Fri, 03 Mar 2017 11:46:56 GMT', 'expertise': ['machine learning', 'vehicle design'], 'jobtitle': 'Software Engineering Lead', 'state': 'CA', 'company': 'Daimler', 'degrees': [], 'jobkey': '78ae00285fc1c5a6', 'longitude': -122.03297}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 78ae00285fc1c5a6
#
# ********* Entry # 7
# {'progskills': [], 'qualifications': ['computer science'], 'country': 'US', 'latitude': 42.357143, 'date': 'Thu, 04 May 2017 15:05:48 GMT', 'expertise': ['autonomous vehicles'], 'jobtitle': 'Front End Software Architect', 'state': 'MA', 'company': 'nuTonomy', 'degrees': ['ms', 'bs'], 'jobkey': '901f6a7a38002a06', 'longitude': -71.05495}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 901f6a7a38002a06
#
# ********* Entry # 8
# {'progskills': [], 'qualifications': [], 'country': 'US', 'latitude': 42.37088, 'date': 'Wed, 10 May 2017 21:51:08 GMT', 'expertise': [], 'jobtitle': 'Technical Analyst', 'state': 'MI', 'company': 'MOBIS NORTH AMERICA, LLC', 'degrees': ['bachelors', 'ms'], 'jobkey': '679f086048dbb4cc', 'longitude': -83.46703}
# job entry already recorded: False
# Job entry saved in DB
# Jobkey 679f086048dbb4cc
#
# ********* Entry # 9
# {'progskills': ['c', 'matlab'], 'qualifications': ['electrical engineering'], 'country': 'US', 'latitude': 37.368134, 'date': 'Thu, 11 May 2017 18:14:52 GMT', 'expertise': ['machine learning'], 'jobtitle': 'ADAS Engineer I', 'state': 'CA', 'company': 'Hitachi Automotive Systems Americas, Inc.', 'degrees': ['bachelor'], 'jobkey': '0788603c87af9478', 'longitude': -122.03297}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 0788603c87af9478
#
# ********* Entry # 10
# {'progskills': [], 'qualifications': [], 'country': 'US', 'latitude': 33.766483, 'date': 'Wed, 10 May 2017 23:25:30 GMT', 'expertise': ['machine learning', 'vehicle design'], 'jobtitle': 'Test Engineer – Mercedes Me Connect', 'state': 'CA', 'company': 'Daimler', 'degrees': [], 'jobkey': '972188973c0efc98', 'longitude': -118.18681}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 972188973c0efc98
#
# ********* Entry # 11
# {'progskills': ['python'], 'qualifications': ['cs'], 'country': 'US', 'latitude': 37.35165, 'date': 'Fri, 17 Mar 2017 05:33:08 GMT', 'expertise': ['autonomous vehicles'], 'jobtitle': 'Deep Learning Data Search Software Engineer\u200b', 'state': 'CA', 'company': 'NVIDIA', 'degrees': [], 'jobkey': '04231c2a529f25c7', 'longitude': -121.95055}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 04231c2a529f25c7
#
# ********* Entry # 12
# {'progskills': ['c++', 'python'], 'qualifications': [], 'country': 'US', 'latitude': 37.43956, 'date': 'Sat, 13 May 2017 03:09:10 GMT', 'expertise': ['machine learning'], 'jobtitle': 'Autonomous Driving Deep Learning Senior Expert', 'state': 'CA', 'company': 'Bosch Group', 'degrees': [], 'jobkey': 'ffb644ef44725269', 'longitude': -122.14286}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey ffb644ef44725269
#
# ********* Entry # 13
# {'progskills': ['c++', 'python', 'ros'], 'qualifications': ['computer science'], 'country': 'US', 'latitude': 37.43956, 'date': 'Sun, 16 Apr 2017 08:09:49 GMT', 'expertise': ['machine learning', 'autonomous vehicles', 'robotics'], 'jobtitle': 'Autonomous Driving Mapping and Localization Research Engineer', 'state': 'CA', 'company': 'Bosch', 'degrees': [], 'jobkey': '25bed7d46addf581', 'longitude': -122.14286}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 25bed7d46addf581
#
# ********* Entry # 14
# {'progskills': ['c++', 'python', 'ros', 'c'], 'qualifications': ['computer science'], 'country': 'US', 'latitude': 37.43956, 'date': 'Sun, 16 Apr 2017 08:09:48 GMT', 'expertise': ['robotics', 'autonomous vehicles'], 'jobtitle': 'Autonomous Driving Perception Research Engineer', 'state': 'CA', 'company': 'Bosch', 'degrees': [], 'jobkey': '126b8947f4ea93c9', 'longitude': -122.14286}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 126b8947f4ea93c9
#
# ********* Entry # 15
# {'progskills': [], 'qualifications': ['computer science'], 'country': 'US', 'latitude': 33.766483, 'date': 'Tue, 09 May 2017 23:23:01 GMT', 'expertise': ['machine learning', 'vehicle design'], 'jobtitle': 'Project Manager, Telematics System Integration', 'state': 'CA', 'company': 'Daimler', 'degrees': ['bachelor'], 'jobkey': 'c1c52f561105ec80', 'longitude': -118.18681}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey c1c52f561105ec80
#
# ********* Entry # 16
# {'progskills': ['c', 'c++', 'matlab'], 'qualifications': ['electrical engineering', 'computer science'], 'country': 'US', 'latitude': 37.29121, 'date': 'Sun, 07 May 2017 10:23:27 GMT', 'expertise': ['autonomous vehicles'], 'jobtitle': 'Lead SW Algorithm Architect', 'state': 'CA', 'company': 'Intel', 'degrees': [], 'jobkey': 'c18cd3714de3154a', 'longitude': -121.89561}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey c18cd3714de3154a
#
# ********* Entry # 17
# {'progskills': [], 'qualifications': [], 'country': 'US', 'latitude': 42.32967, 'date': 'Sat, 22 Apr 2017 04:27:50 GMT', 'expertise': [], 'jobtitle': 'Programmer/Analyst - INF0019496', 'state': 'MI', 'company': 'General Motors', 'degrees': ['bachelor'], 'jobkey': '67849c161a3aab4b', 'longitude': -83.04395}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 67849c161a3aab4b
#
# ********* Entry # 18
# {'progskills': [], 'qualifications': [], 'country': 'US', 'latitude': 33.766483, 'date': 'Wed, 05 Apr 2017 05:17:55 GMT', 'expertise': ['machine learning', 'vehicle design'], 'jobtitle': 'Procurement Specialist', 'state': 'CA', 'company': 'Daimler', 'degrees': ['bachelor', 'ms'], 'jobkey': '2e757d3caebf3ffb', 'longitude': -118.18681}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 2e757d3caebf3ffb
#
# ********* Entry # 19
# {'progskills': ['c++', 'python', 'ros'], 'qualifications': ['computer science'], 'country': 'US', 'latitude': 37.43956, 'date': 'Sat, 15 Apr 2017 08:03:49 GMT', 'expertise': ['robotics', 'machine learning', 'autonomous vehicles'], 'jobtitle': 'Autonomous Driving Planning Research Engineer', 'state': 'CA', 'company': 'Bosch', 'degrees': [], 'jobkey': '77ff4b50a1808bbd', 'longitude': -122.14286}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 77ff4b50a1808bbd
#
# ********* Entry # 20
# {'progskills': [], 'qualifications': [], 'country': 'US', 'latitude': 42.381866, 'date': 'Fri, 05 May 2017 23:11:12 GMT', 'expertise': ['machine learning', 'vehicle design'], 'jobtitle': 'Procurement Intern', 'state': 'MI', 'company': 'Daimler', 'degrees': ['bachelors', 'masters'], 'jobkey': '4adb2aa8ef57d0cd', 'longitude': -83.29121}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 4adb2aa8ef57d0cd
#
# ********* Entry # 21
# {'progskills': [], 'qualifications': ['computer science'], 'country': 'US', 'latitude': 37.384617, 'date': 'Tue, 11 Apr 2017 20:05:48 GMT', 'expertise': ['machine learning', 'robotics'], 'jobtitle': 'Research Scientist, Guardian/Autonomous Driving', 'state': 'CA', 'company': 'Toyota Research Institute', 'degrees': [], 'jobkey': '596c930e4503673a', 'longitude': -122.10989}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 596c930e4503673a
#
# ********* Entry # 22
# {'progskills': ['java', 'python'], 'qualifications': ['computer science'], 'country': 'US', 'latitude': 42.32967, 'date': 'Wed, 22 Mar 2017 02:37:56 GMT', 'expertise': [], 'jobtitle': 'IT Systems Analyst - INF0019394', 'state': 'MI', 'company': 'General Motors', 'degrees': ['bachelor', 'masters'], 'jobkey': 'f9a25aaeff42b195', 'longitude': -83.04395}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey f9a25aaeff42b195
#
# ********* Entry # 23
# {'progskills': [], 'qualifications': ['computer science', 'electrical engineering'], 'country': 'US', 'latitude': 32.714287, 'date': 'Thu, 13 Apr 2017 21:27:22 GMT', 'expertise': [], 'jobtitle': 'Software Engineer - Autonomous Driving (Qualcomm Research)', 'state': 'CA', 'company': 'Qualcomm', 'degrees': ['bachelor', 'master'], 'jobkey': '2175750b64f0e9c4', 'longitude': -117.15385}
# job entry already recorded: False
# Job entry saved in DB
# Jobkey 2175750b64f0e9c4
#
# ********* Entry # 24
# {'progskills': [], 'qualifications': [], 'country': 'US', 'latitude': 32.714287, 'date': 'Thu, 04 May 2017 08:05:58 GMT', 'expertise': [], 'jobtitle': 'Business Development Specialist', 'state': 'CA', 'company': 'TuSimple', 'degrees': ['bachelor'], 'jobkey': 'a9a3efffe9dcb43e', 'longitude': -117.15385}
# job entry already recorded: False
# Job entry saved in DB
# Jobkey a9a3efffe9dcb43e
#
# ********* Entry # 25
# {'progskills': ['c++'], 'qualifications': ['computer science'], 'country': 'US', 'latitude': 37.368134, 'date': 'Sat, 13 May 2017 23:31:50 GMT', 'expertise': ['machine learning', 'vehicle design'], 'jobtitle': 'Voice UI Software Engineering Intern', 'state': 'CA', 'company': 'Daimler', 'degrees': [], 'jobkey': '2ed33c82936f4c23', 'longitude': -122.03297}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 2ed33c82936f4c23
#
# 100
# ********* Entry # 1
# {'progskills': [], 'qualifications': ['physics'], 'country': 'US', 'latitude': '', 'date': 'Wed, 03 May 2017 15:00:07 GMT', 'expertise': [], 'jobtitle': 'Component Engineer', 'state': '', 'company': 'Autoliv Inc.', 'degrees': [], 'jobkey': 'e24383166e31ac3f', 'longitude': ''}
# job entry already recorded: False
# Job entry saved in DB
# Jobkey e24383166e31ac3f
#
# ********* Entry # 2
# {'progskills': [], 'qualifications': [], 'country': 'US', 'latitude': 40.697803, 'date': 'Mon, 08 May 2017 17:37:32 GMT', 'expertise': [], 'jobtitle': 'Human Resources Manager', 'state': 'NY', 'company': 'Rosco Vision Systems', 'degrees': ['ba', 'bs', 'bachelor'], 'jobkey': '7bc500a392d38654', 'longitude': -73.7967}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 7bc500a392d38654
#
# ********* Entry # 3
# {'progskills': ['c++', 'python'], 'qualifications': ['computer science'], 'country': 'US', 'latitude': 37.87088, 'date': 'Tue, 11 Apr 2017 07:17:47 GMT', 'expertise': ['machine learning'], 'jobtitle': 'Research Engineer', 'state': 'CA', 'company': 'HERE', 'degrees': ['bachelors', 'ms'], 'jobkey': 'f64c50a40aeaf218', 'longitude': -122.26923}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey f64c50a40aeaf218
#
# ********* Entry # 4
# {'progskills': [], 'qualifications': [], 'country': 'US', 'latitude': 32.714287, 'date': 'Fri, 24 Feb 2017 06:27:13 GMT', 'expertise': [], 'jobtitle': 'Pilot (Driver) & Concierge', 'state': 'CA', 'company': 'Tesloop', 'degrees': [], 'jobkey': 'ee846a17dbf6fb6b', 'longitude': -117.15385}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey ee846a17dbf6fb6b
#
# ********* Entry # 5
# {'progskills': ['c++', 'matlab', 'c'], 'qualifications': ['ee', 'cs', 'ce'], 'country': 'US', 'latitude': 40.332417, 'date': 'Tue, 14 Mar 2017 14:00:33 GMT', 'expertise': ['machine learning', 'robotics'], 'jobtitle': 'C++ hardware design engineer', 'state': 'NJ', 'company': 'Kite Staffing', 'degrees': ['bachelor', 'bs', 'ms', 'phd'], 'jobkey': '1b8d1f19fba6b0d5', 'longitude': -74.5989}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 1b8d1f19fba6b0d5
#
# ********* Entry # 6
# {'progskills': ['c', 'c++'], 'qualifications': ['computer science'], 'country': 'US', 'latitude': 40.53022, 'date': 'Thu, 11 May 2017 10:25:40 GMT', 'expertise': ['robotics'], 'jobtitle': 'Systems Administrator', 'state': 'PA', 'company': 'Delphi', 'degrees': ['bs'], 'jobkey': '5d05ec49a5590435', 'longitude': -79.87363}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 5d05ec49a5590435
#
# ********* Entry # 7
# {'progskills': ['c', 'c++', 'java', 'python'], 'qualifications': ['computer science'], 'country': 'US', 'latitude': 42.381866, 'date': 'Mon, 08 May 2017 23:21:41 GMT', 'expertise': ['machine learning', 'vehicle design', 'computer architecture'], 'jobtitle': 'Engineering Intern - Core Software', 'state': 'MI', 'company': 'Daimler', 'degrees': [], 'jobkey': 'e146559401107f0e', 'longitude': -83.29121}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey e146559401107f0e
#
# ********* Entry # 8
# {'progskills': [], 'qualifications': ['mechanical engineering', 'electrical engineering'], 'country': 'US', 'latitude': 33.766483, 'date': 'Mon, 08 May 2017 23:21:42 GMT', 'expertise': ['machine learning', 'vehicle design'], 'jobtitle': 'Engineering Intern - Advanced Driver Assistance Systems and Durability', 'state': 'CA', 'company': 'Daimler', 'degrees': ['ms'], 'jobkey': '0553cf55af2eecd8', 'longitude': -118.18681}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 0553cf55af2eecd8
#
# ********* Entry # 9
# {'progskills': ['c'], 'qualifications': [], 'country': 'US', 'latitude': 33.5, 'date': 'Thu, 06 Apr 2017 10:22:11 GMT', 'expertise': [], 'jobtitle': 'Security Engineer Automotive', 'state': 'AZ', 'company': 'Intel', 'degrees': ['bachelors', 'master'], 'jobkey': '9b265615167e1a39', 'longitude': -111.97802}
# ...
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 3cba11c1493a363d
#
# ********* Entry # 4
# {'progskills': ['java'], 'qualifications': [], 'country': 'US', 'latitude': 42.32967, 'date': 'Fri, 14 Apr 2017 04:00:51 GMT', 'expertise': [], 'jobtitle': 'IT Software Developer - INF0019457', 'state': 'MI', 'company': 'General Motors', 'degrees': ['bachelor'], 'jobkey': '9f44299c52c13241', 'longitude': -83.04395}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 9f44299c52c13241
#
# 4825
# ********* Entry # 1
# {'progskills': [], 'qualifications': ['electrical engineering'], 'country': 'US', 'latitude': 42.66209, 'date': 'Thu, 06 Apr 2017 03:32:12 GMT', 'expertise': [], 'jobtitle': 'Lead Autonomous Driving (AV) Controller Integration and Verification Engineer - GPS0001574', 'state': 'MI', 'company': 'General Motors', 'degrees': ['ms'], 'jobkey': '28d09d61828839cd', 'longitude': -83.28039}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 28d09d61828839cd
#
# ********* Entry # 2
# ********* Entry # 3
# {'progskills': [], 'qualifications': ['electrical engineering', 'computer science'], 'country': 'US', 'latitude': 42.475273, 'date': 'Fri, 07 Apr 2017 03:36:04 GMT', 'expertise': ['vehicle development'], 'jobtitle': 'Autonomous Driving Advanced Software Engineering Group Manager - ENG0034486', 'state': 'MI', 'company': 'General Motors', 'degrees': ['bs', 'master'], 'jobkey': '3cba11c1493a363d', 'longitude': -83.02747}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 3cba11c1493a363d
#
# ********* Entry # 4
# {'progskills': ['java'], 'qualifications': [], 'country': 'US', 'latitude': 42.32967, 'date': 'Fri, 14 Apr 2017 04:00:51 GMT', 'expertise': [], 'jobtitle': 'IT Software Developer - INF0019457', 'state': 'MI', 'company': 'General Motors', 'degrees': ['bachelor'], 'jobkey': '9f44299c52c13241', 'longitude': -83.04395}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 9f44299c52c13241
#
# 4850
# ********* Entry # 1
# {'progskills': [], 'qualifications': ['electrical engineering'], 'country': 'US', 'latitude': 42.66209, 'date': 'Thu, 06 Apr 2017 03:32:12 GMT', 'expertise': [], 'jobtitle': 'Lead Autonomous Driving (AV) Controller Integration and Verification Engineer - GPS0001574', 'state': 'MI', 'company': 'General Motors', 'degrees': ['ms'], 'jobkey': '28d09d61828839cd', 'longitude': -83.28039}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 28d09d61828839cd
#
# ********* Entry # 2
# ********* Entry # 3
# {'progskills': [], 'qualifications': ['electrical engineering', 'computer science'], 'country': 'US', 'latitude': 42.475273, 'date': 'Fri, 07 Apr 2017 03:36:04 GMT', 'expertise': ['vehicle development'], 'jobtitle': 'Autonomous Driving Advanced Software Engineering Group Manager - ENG0034486', 'state': 'MI', 'company': 'General Motors', 'degrees': ['bs', 'master'], 'jobkey': '3cba11c1493a363d', 'longitude': -83.02747}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 3cba11c1493a363d
#
# ********* Entry # 4
# {'progskills': ['java'], 'qualifications': [], 'country': 'US', 'latitude': 42.32967, 'date': 'Fri, 14 Apr 2017 04:00:51 GMT', 'expertise': [], 'jobtitle': 'IT Software Developer - INF0019457', 'state': 'MI', 'company': 'General Motors', 'degrees': ['bachelor'], 'jobkey': '9f44299c52c13241', 'longitude': -83.04395}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 9f44299c52c13241
#
# 4875
# ********* Entry # 1
# {'progskills': [], 'qualifications': ['electrical engineering'], 'country': 'US', 'latitude': 42.66209, 'date': 'Thu, 06 Apr 2017 03:32:12 GMT', 'expertise': [], 'jobtitle': 'Lead Autonomous Driving (AV) Controller Integration and Verification Engineer - GPS0001574', 'state': 'MI', 'company': 'General Motors', 'degrees': ['ms'], 'jobkey': '28d09d61828839cd', 'longitude': -83.28039}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 28d09d61828839cd
#
# ********* Entry # 2
# ********* Entry # 3
# {'progskills': [], 'qualifications': ['electrical engineering', 'computer science'], 'country': 'US', 'latitude': 42.475273, 'date': 'Fri, 07 Apr 2017 03:36:04 GMT', 'expertise': ['vehicle development'], 'jobtitle': 'Autonomous Driving Advanced Software Engineering Group Manager - ENG0034486', 'state': 'MI', 'company': 'General Motors', 'degrees': ['bs', 'master'], 'jobkey': '3cba11c1493a363d', 'longitude': -83.02747}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 3cba11c1493a363d
#
# ********* Entry # 4
# {'progskills': ['java'], 'qualifications': [], 'country': 'US', 'latitude': 42.32967, 'date': 'Fri, 14 Apr 2017 04:00:51 GMT', 'expertise': [], 'jobtitle': 'IT Software Developer - INF0019457', 'state': 'MI', 'company': 'General Motors', 'degrees': ['bachelor'], 'jobkey': '9f44299c52c13241', 'longitude': -83.04395}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 9f44299c52c13241
#
# 4900
# ********* Entry # 1
# {'progskills': [], 'qualifications': ['electrical engineering'], 'country': 'US', 'latitude': 42.66209, 'date': 'Thu, 06 Apr 2017 03:32:12 GMT', 'expertise': [], 'jobtitle': 'Lead Autonomous Driving (AV) Controller Integration and Verification Engineer - GPS0001574', 'state': 'MI', 'company': 'General Motors', 'degrees': ['ms'], 'jobkey': '28d09d61828839cd', 'longitude': -83.28039}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 28d09d61828839cd
#
# ********* Entry # 2
# ********* Entry # 3
# {'progskills': [], 'qualifications': ['electrical engineering', 'computer science'], 'country': 'US', 'latitude': 42.475273, 'date': 'Fri, 07 Apr 2017 03:36:04 GMT', 'expertise': ['vehicle development'], 'jobtitle': 'Autonomous Driving Advanced Software Engineering Group Manager - ENG0034486', 'state': 'MI', 'company': 'General Motors', 'degrees': ['bs', 'master'], 'jobkey': '3cba11c1493a363d', 'longitude': -83.02747}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 3cba11c1493a363d
#
# ********* Entry # 4
# {'progskills': ['java'], 'qualifications': [], 'country': 'US', 'latitude': 42.32967, 'date': 'Fri, 14 Apr 2017 04:00:51 GMT', 'expertise': [], 'jobtitle': 'IT Software Developer - INF0019457', 'state': 'MI', 'company': 'General Motors', 'degrees': ['bachelor'], 'jobkey': '9f44299c52c13241', 'longitude': -83.04395}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 9f44299c52c13241
#
# 4925
# ********* Entry # 1
# {'progskills': [], 'qualifications': ['electrical engineering'], 'country': 'US', 'latitude': 42.66209, 'date': 'Thu, 06 Apr 2017 03:32:12 GMT', 'expertise': [], 'jobtitle': 'Lead Autonomous Driving (AV) Controller Integration and Verification Engineer - GPS0001574', 'state': 'MI', 'company': 'General Motors', 'degrees': ['ms'], 'jobkey': '28d09d61828839cd', 'longitude': -83.28039}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 28d09d61828839cd
#
# ********* Entry # 2
# ********* Entry # 3
# {'progskills': [], 'qualifications': ['electrical engineering', 'computer science'], 'country': 'US', 'latitude': 42.475273, 'date': 'Fri, 07 Apr 2017 03:36:04 GMT', 'expertise': ['vehicle development'], 'jobtitle': 'Autonomous Driving Advanced Software Engineering Group Manager - ENG0034486', 'state': 'MI', 'company': 'General Motors', 'degrees': ['bs', 'master'], 'jobkey': '3cba11c1493a363d', 'longitude': -83.02747}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 3cba11c1493a363d
#
# ********* Entry # 4
# {'progskills': ['java'], 'qualifications': [], 'country': 'US', 'latitude': 42.32967, 'date': 'Fri, 14 Apr 2017 04:00:51 GMT', 'expertise': [], 'jobtitle': 'IT Software Developer - INF0019457', 'state': 'MI', 'company': 'General Motors', 'degrees': ['bachelor'], 'jobkey': '9f44299c52c13241', 'longitude': -83.04395}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 9f44299c52c13241
#
# 4950
# ********* Entry # 1
# {'progskills': [], 'qualifications': ['electrical engineering'], 'country': 'US', 'latitude': 42.66209, 'date': 'Thu, 06 Apr 2017 03:32:12 GMT', 'expertise': [], 'jobtitle': 'Lead Autonomous Driving (AV) Controller Integration and Verification Engineer - GPS0001574', 'state': 'MI', 'company': 'General Motors', 'degrees': ['ms'], 'jobkey': '28d09d61828839cd', 'longitude': -83.28039}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 28d09d61828839cd
#
# ********* Entry # 2
# ********* Entry # 3
# {'progskills': [], 'qualifications': ['electrical engineering', 'computer science'], 'country': 'US', 'latitude': 42.475273, 'date': 'Fri, 07 Apr 2017 03:36:04 GMT', 'expertise': ['vehicle development'], 'jobtitle': 'Autonomous Driving Advanced Software Engineering Group Manager - ENG0034486', 'state': 'MI', 'company': 'General Motors', 'degrees': ['bs', 'master'], 'jobkey': '3cba11c1493a363d', 'longitude': -83.02747}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 3cba11c1493a363d
#
# ********* Entry # 4
# {'progskills': ['java'], 'qualifications': [], 'country': 'US', 'latitude': 42.32967, 'date': 'Fri, 14 Apr 2017 04:00:51 GMT', 'expertise': [], 'jobtitle': 'IT Software Developer - INF0019457', 'state': 'MI', 'company': 'General Motors', 'degrees': ['bachelor'], 'jobkey': '9f44299c52c13241', 'longitude': -83.04395}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 9f44299c52c13241
#
# 4975
# ********* Entry # 1
# {'progskills': [], 'qualifications': ['electrical engineering'], 'country': 'US', 'latitude': 42.66209, 'date': 'Thu, 06 Apr 2017 03:32:12 GMT', 'expertise': [], 'jobtitle': 'Lead Autonomous Driving (AV) Controller Integration and Verification Engineer - GPS0001574', 'state': 'MI', 'company': 'General Motors', 'degrees': ['ms'], 'jobkey': '28d09d61828839cd', 'longitude': -83.28039}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 28d09d61828839cd
#
# ********* Entry # 2
# ********* Entry # 3
# {'progskills': [], 'qualifications': ['electrical engineering', 'computer science'], 'country': 'US', 'latitude': 42.475273, 'date': 'Fri, 07 Apr 2017 03:36:04 GMT', 'expertise': ['vehicle development'], 'jobtitle': 'Autonomous Driving Advanced Software Engineering Group Manager - ENG0034486', 'state': 'MI', 'company': 'General Motors', 'degrees': ['bs', 'master'], 'jobkey': '3cba11c1493a363d', 'longitude': -83.02747}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 3cba11c1493a363d
#
# ********* Entry # 4
# {'progskills': ['java'], 'qualifications': [], 'country': 'US', 'latitude': 42.32967, 'date': 'Fri, 14 Apr 2017 04:00:51 GMT', 'expertise': [], 'jobtitle': 'IT Software Developer - INF0019457', 'state': 'MI', 'company': 'General Motors', 'degrees': ['bachelor'], 'jobkey': '9f44299c52c13241', 'longitude': -83.04395}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 9f44299c52c13241
#
# 5000
# ********* Entry # 1
# {'progskills': [], 'qualifications': ['electrical engineering'], 'country': 'US', 'latitude': 42.66209, 'date': 'Thu, 06 Apr 2017 03:32:12 GMT', 'expertise': [], 'jobtitle': 'Lead Autonomous Driving (AV) Controller Integration and Verification Engineer - GPS0001574', 'state': 'MI', 'company': 'General Motors', 'degrees': ['ms'], 'jobkey': '28d09d61828839cd', 'longitude': -83.28039}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 28d09d61828839cd
#
# ********* Entry # 2
# ********* Entry # 3
# {'progskills': [], 'qualifications': ['electrical engineering', 'computer science'], 'country': 'US', 'latitude': 42.475273, 'date': 'Fri, 07 Apr 2017 03:36:04 GMT', 'expertise': ['vehicle development'], 'jobtitle': 'Autonomous Driving Advanced Software Engineering Group Manager - ENG0034486', 'state': 'MI', 'company': 'General Motors', 'degrees': ['bs', 'master'], 'jobkey': '3cba11c1493a363d', 'longitude': -83.02747}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 3cba11c1493a363d
#
# ********* Entry # 4
# {'progskills': ['java'], 'qualifications': [], 'country': 'US', 'latitude': 42.32967, 'date': 'Fri, 14 Apr 2017 04:00:51 GMT', 'expertise': [], 'jobtitle': 'IT Software Developer - INF0019457', 'state': 'MI', 'company': 'General Motors', 'degrees': ['bachelor'], 'jobkey': '9f44299c52c13241', 'longitude': -83.04395}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 9f44299c52c13241
#
# 5025
# ********* Entry # 1
# {'progskills': [], 'qualifications': ['electrical engineering'], 'country': 'US', 'latitude': 42.66209, 'date': 'Thu, 06 Apr 2017 03:32:12 GMT', 'expertise': [], 'jobtitle': 'Lead Autonomous Driving (AV) Controller Integration and Verification Engineer - GPS0001574', 'state': 'MI', 'company': 'General Motors', 'degrees': ['ms'], 'jobkey': '28d09d61828839cd', 'longitude': -83.28039}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 28d09d61828839cd
#
# ********* Entry # 2
# ********* Entry # 3
# {'progskills': [], 'qualifications': ['electrical engineering', 'computer science'], 'country': 'US', 'latitude': 42.475273, 'date': 'Fri, 07 Apr 2017 03:36:04 GMT', 'expertise': ['vehicle development'], 'jobtitle': 'Autonomous Driving Advanced Software Engineering Group Manager - ENG0034486', 'state': 'MI', 'company': 'General Motors', 'degrees': ['bs', 'master'], 'jobkey': '3cba11c1493a363d', 'longitude': -83.02747}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 3cba11c1493a363d
#
# ********* Entry # 4
# {'progskills': ['java'], 'qualifications': [], 'country': 'US', 'latitude': 42.32967, 'date': 'Fri, 14 Apr 2017 04:00:51 GMT', 'expertise': [], 'jobtitle': 'IT Software Developer - INF0019457', 'state': 'MI', 'company': 'General Motors', 'degrees': ['bachelor'], 'jobkey': '9f44299c52c13241', 'longitude': -83.04395}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 9f44299c52c13241
#
# 5050
# ********* Entry # 1
# {'progskills': [], 'qualifications': ['electrical engineering'], 'country': 'US', 'latitude': 42.66209, 'date': 'Thu, 06 Apr 2017 03:32:12 GMT', 'expertise': [], 'jobtitle': 'Lead Autonomous Driving (AV) Controller Integration and Verification Engineer - GPS0001574', 'state': 'MI', 'company': 'General Motors', 'degrees': ['ms'], 'jobkey': '28d09d61828839cd', 'longitude': -83.28039}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 28d09d61828839cd
#
# ********* Entry # 2
# ********* Entry # 3
# {'progskills': [], 'qualifications': ['electrical engineering', 'computer science'], 'country': 'US', 'latitude': 42.475273, 'date': 'Fri, 07 Apr 2017 03:36:04 GMT', 'expertise': ['vehicle development'], 'jobtitle': 'Autonomous Driving Advanced Software Engineering Group Manager - ENG0034486', 'state': 'MI', 'company': 'General Motors', 'degrees': ['bs', 'master'], 'jobkey': '3cba11c1493a363d', 'longitude': -83.02747}
# job entry already recorded: True
# Unable to save job entry in jobs
# Jobkey 3cba11c1493a363d
#
# ********* Entry # 4
# page not found
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-502c8511870c> in <module>()
#      21
#      22 #
# ---> 23 jobsScrap.record(keywords, start, limit)
#
# <ipython-input-17-ded6710fb9cd> in record(self, keywords, start, limit)
#     237
#     238                     #extract job requirements from job description
# --> 239                     job_req = self.extract_jobRequirements(jobkey)
#     240                     job_specs = {**job_details, **job_req}
#     241                     print(job_specs)
#
# <ipython-input-17-ded6710fb9cd> in extract_jobRequirements(self, jobkey)
#     177
#     178         #better to scroll thru text once
# --> 179         for idx, word in enumerate(job_description_txt):
#     180             w_lower = word.lower()
#     181
#
# TypeError: 'NoneType' object is not iterable

# %%
## Data analysis - search for outliers i.e jobs that have nothign to do with SDC
# 1st approach is to list all unique companies

1. remove universities
2. remove manager position

# %%
def connect_db():
    sql_files = glob.glob('indeed.db')
    conn = sqlite3.connect('indeed')
    c = conn.cursor()

connect_db()

# %%
conn = sqlite3.connect('indeed.db')
c = conn.cursor()
#select in jobs all unique values in column = employer
sql_manager = "SELECT jobkey FROM jobs WHERE jobkey='b7085bc714cbc23e';"
c.execute(sql_manager)
result = c.fetchall()
print(len(result))
for jk in result:
    jk = jk[0]
    try:
        sql_delete = "DELETE FROM jobs WHERE jobkey='{}';".format(jk)
        c.execute(sql_delete)
        conn.commit()
    except:
        print('could not delete {} from table: jobs')
        
    try:
        sql_delete = "DELETE FROM degrees WHERE jobkey='{}';".format(jk)
        c.execute(sql_delete)
        conn.commit()
    except:
        print('could not delete {} from table: degrees')    
    try:
        sql_delete = "DELETE FROM expertise WHERE jobkey='{}';".format(jk)
        c.execute(sql_delete)
        conn.commit()
    except:
        print('could not delete {} from table: expertise')
    try:
        sql_delete = "DELETE FROM progskills WHERE jobkey='{}';".format(jk)
        c.execute(sql_delete)
        conn.commit()
    except:
        print('could not delete {} from table: progskills')
    try:
        sql_delete = "DELETE FROM qualifications WHERE jobkey='{}';".format(jk)
        c.execute(sql_delete)
        conn.commit()
    except:
        print('could not delete {} from table: qualifications')
c.execute(sql_manager)
result = c.fetchall()
# Out:
# 1

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt


conn = sqlite3.connect('indeed.db')
c = conn.cursor()
#select in jobs all unique values in column = employer
sql_manager = "SELECT * FROM jobs;"
c.execute(sql_manager)
result = c.fetchall()
print(len(result))
data_pts = []        
for entry in result:
    data_pts.append([entry['longitudinal, lateral']])

def mapTut(pts):

    m = Basemap(projection='mill',llcrnrlat=20,urcrnrlat=50,\
                llcrnrlon=-130,urcrnrlon=-60,resolution='c')
    m.drawcoastlines()
    m.drawcountries()
    m.drawstates()
    m.fillcontinents(color='#04BAE3',lake_color='#FFFFFF')
    m.drawmapboundary(fill_color='#FFFFFF')

    for point in pts:
        lat, lo = point[1], point[0]
        x,y = m(lon,lat)
        m.plot(x,y, 'ro')
   
    # Houston, Texas


    
    plt.title("Geo Plotting")
    plt.show()


mapTut(data_pts)
# Out:
# 0
